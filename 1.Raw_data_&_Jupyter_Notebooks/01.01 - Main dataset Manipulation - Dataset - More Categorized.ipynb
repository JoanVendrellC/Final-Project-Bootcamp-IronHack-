# %% [markdown]
# # Accidents Main Dataset manipulation (More categorized)

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
import statistics

# %%
import sys
np.set_printoptions(threshold=sys.maxsize)
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import r2_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# %% [markdown]
# # read all data

# %%
Accidents = pd.read_csv('Accidents_de_tr_nsit_amb_morts_o_ferits_greus_a_Catalunya.csv')

# %% [markdown]
# # check the data

# %%
Accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21161 entries, 0 to 21160
# Data columns (total 58 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Any                        21161 non-null  int64
#  1   zona                       21161 non-null  object
#  2   dat                        21161 non-null  object
#  3   via                        21161 non-null  object
#  4   pk                         21160 non-null  object
#  5   nomMun                     21161 non-null  object
#  6   nomCom                     21161 non-null  object
#  7   nomDem                     21161 non-null  object
#  8   F_MORTS                    21161 non-null  int64
#  9   F_FERITS_GREUS             21161 non-null  int64
#  10  F_FERITS_LLEUS             21161 non-null  int64
#  11  F_VICTIMES                 21161 non-null  int64
#  12  F_UNITATS_IMPLICADES       21161 non-null  int64
#  13  F_VIANANTS_IMPLICADES      21161 non-null  int64
#  14  F_BICICLETES_IMPLICADES    21161 non-null  int64
#  15  F_CICLOMOTORS_IMPLICADES   21161 non-null  int64
#  16  F_MOTOCICLETES_IMPLICADES  21161 non-null  int64
#  17  F_VEH_LLEUGERS_IMPLICADES  21161 non-null  int64
#  18  F_VEH_PESANTS_IMPLICADES   21161 non-null  int64
#  19  F_ALTRES_UNIT_IMPLICADES   21161 non-null  int64
#  20  F_UNIT_DESC_IMPLICADES     21161 non-null  int64
#  21  C_VELOCITAT_VIA            18519 non-null  float64
#  22  D_ACC_AMB_FUGA             21161 non-null  object
#  23  D_BOIRA                    21161 non-null  object
#  24  D_CARACT_ENTORN            21129 non-null  object
#  25  D_CARRIL_ESPECIAL          19812 non-null  object
#  26  D_CIRCULACIO_MESURES_ESP   21121 non-null  object
#  27  D_CLIMATOLOGIA             21161 non-null  object
#  28  D_FUNC_ESP_VIA             21161 non-null  object
#  29  D_GRAVETAT                 21161 non-null  object
#  30  D_INFLUIT_BOIRA            21161 non-null  object
#  31  D_INFLUIT_CARACT_ENTORN    21161 non-null  object
#  32  D_INFLUIT_CIRCULACIO       21161 non-null  object
#  33  D_INFLUIT_ESTAT_CLIMA      21161 non-null  object
#  34  D_INFLUIT_INTEN_VENT       21161 non-null  object
#  35  D_INFLUIT_LLUMINOSITAT     21161 non-null  object
#  36  D_INFLUIT_MESU_ESP         21161 non-null  object
#  37  D_INFLUIT_OBJ_CALCADA      21161 non-null  object
#  38  D_INFLUIT_SOLCS_RASES      21161 non-null  object
#  39  D_INFLUIT_VISIBILITAT      21161 non-null  object
#  40  D_INTER_SECCIO             21161 non-null  object
#  41  D_LIMIT_VELOCITAT          21161 non-null  object
#  42  D_LLUMINOSITAT             21161 non-null  object
#  43  D_REGULACIO_PRIORITAT      6191 non-null   object
#  44  D_SENTITS_VIA              17665 non-null  object
#  45  D_SUBTIPUS_ACCIDENT        21161 non-null  object
#  46  D_SUBTIPUS_TRAM            6949 non-null   object
#  47  D_SUBZONA                  21161 non-null  object
#  48  D_SUPERFICIE               21161 non-null  object
#  49  D_TIPUS_VIA                21161 non-null  object
#  50  D_TITULARITAT_VIA          10449 non-null  object
#  51  D_TRACAT_ALTIMETRIC        13524 non-null  object
#  52  D_VENT                     21161 non-null  object
#  53  grupDiaLab                 21161 non-null  object
#  54  hor                        21161 non-null  object
#  55  grupHor                    21161 non-null  object
#  56  tipAcc                     21161 non-null  object
#  57  tipDia                     21161 non-null  object
# dtypes: float64(1), int64(14), object(43)
# memory usage: 9.4+ MB

# %% [markdown]
# # Renaming columns with lowercase

# %%
Accidents.columns=[e.lower().replace(' ', '_') for e in Accidents.columns]
Accidents.columns
# Out:
# Index(['any', 'zona', 'dat', 'via', 'pk', 'nommun', 'nomcom', 'nomdem',
#        'f_morts', 'f_ferits_greus', 'f_ferits_lleus', 'f_victimes',
#        'f_unitats_implicades', 'f_vianants_implicades',
#        'f_bicicletes_implicades', 'f_ciclomotors_implicades',
#        'f_motocicletes_implicades', 'f_veh_lleugers_implicades',
#        'f_veh_pesants_implicades', 'f_altres_unit_implicades',
#        'f_unit_desc_implicades', 'c_velocitat_via', 'd_acc_amb_fuga',
#        'd_boira', 'd_caract_entorn', 'd_carril_especial',
#        'd_circulacio_mesures_esp', 'd_climatologia', 'd_func_esp_via',
#        'd_gravetat', 'd_influit_boira', 'd_influit_caract_entorn',
#        'd_influit_circulacio', 'd_influit_estat_clima', 'd_influit_inten_vent',
#        'd_influit_lluminositat', 'd_influit_mesu_esp', 'd_influit_obj_calcada',
#        'd_influit_solcs_rases', 'd_influit_visibilitat', 'd_inter_seccio',
#        'd_limit_velocitat', 'd_lluminositat', 'd_regulacio_prioritat',
#        'd_sentits_via', 'd_subtipus_accident', 'd_subtipus_tram', 'd_subzona',
#        'd_superficie', 'd_tipus_via', 'd_titularitat_via',
#        'd_tracat_altimetric', 'd_vent', 'grupdialab', 'hor', 'gruphor',
#        'tipacc', 'tipdia'],
#       dtype='object')

# %% [markdown]
# # Check the NaN values

# %%
Accidents.isna().sum()
# Out:
# any                              0
# zona                             0
# dat                              0
# via                              0
# pk                               1
# nommun                           0
# nomcom                           0
# nomdem                           0
# f_morts                          0
# f_ferits_greus                   0
# f_ferits_lleus                   0
# f_victimes                       0
# f_unitats_implicades             0
# f_vianants_implicades            0
# f_bicicletes_implicades          0
# f_ciclomotors_implicades         0
# f_motocicletes_implicades        0
# f_veh_lleugers_implicades        0
# f_veh_pesants_implicades         0
# f_altres_unit_implicades         0
# f_unit_desc_implicades           0
# c_velocitat_via               2642
# d_acc_amb_fuga                   0
# d_boira                          0
# d_caract_entorn                 32
# d_carril_especial             1349
# d_circulacio_mesures_esp        40
# d_climatologia                   0
# d_func_esp_via                   0
# d_gravetat                       0
# d_influit_boira                  0
# d_influit_caract_entorn          0
# d_influit_circulacio             0
# d_influit_estat_clima            0
# d_influit_inten_vent             0
# d_influit_lluminositat           0
# d_influit_mesu_esp               0
# d_influit_obj_calcada            0
# d_influit_solcs_rases            0
# d_influit_visibilitat            0
# d_inter_seccio                   0
# d_limit_velocitat                0
# d_lluminositat                   0
# d_regulacio_prioritat        14970
# d_sentits_via                 3496
# d_subtipus_accident              0
# d_subtipus_tram              14212
# d_subzona                        0
# d_superficie                     0
# d_tipus_via                      0
# d_titularitat_via            10712
# d_tracat_altimetric           7637
# d_vent                           0
# grupdialab                       0
# hor                              0
# gruphor                          0
# tipacc                           0
# tipdia                           0
# dtype: int64

# %% [markdown]
# # get only the columns with NaN values

# %%
nulls_percent_Accidents = pd.DataFrame(Accidents.isna().sum()/len(Accidents)).reset_index()
nulls_percent_Accidents.columns = ['column_name', 'nulls_percentage']
nulls_percent_Accidents[nulls_percent_Accidents['nulls_percentage']!=0]
# Out:
#                  column_name  nulls_percentage
# 4                         pk          0.000047
# 21           c_velocitat_via          0.124852
# 24           d_caract_entorn          0.001512
# 25         d_carril_especial          0.063749
# 26  d_circulacio_mesures_esp          0.001890
# 43     d_regulacio_prioritat          0.707433
# 44             d_sentits_via          0.165210
# 46           d_subtipus_tram          0.671613
# 50         d_titularitat_via          0.506214
# 51       d_tracat_altimetric          0.360900

# %% [markdown]
# # cleaning the NaN values column pk

# %%
Accidents['pk'].value_counts(dropna=False)
# Out:
# 999999    11006
# 1           173
# 0           161
# 2            92
# 3            86
#           ...
# 256,2         1
# 743,9         1
# 58,1          1
# 134,2         1
# 63,5          1
# Name: pk, Length: 2804, dtype: int64

# %%
Accidents['pk'].nunique()
# Out:
# 2803

# %%
Accidents['pk']=Accidents['pk'].fillna('0')

def cleankSymbol(x):
    if x in ['999999']:
        return '0'
    else:
        return x
    
Accidents['pk'] = list(map(cleankSymbol, Accidents['pk']))
Accidents['pk'].value_counts(dropna=False)
# Out:
# 0        11168
# 1          173
# 2           92
# 3           86
# 1,5         82
#          ...
# 256,2        1
# 743,9        1
# 58,1         1
# 134,2        1
# 63,5         1
# Name: pk, Length: 2802, dtype: int64

# %% [markdown]
# # cleaning the NaN values column c_velocitat_via

# %%
Accidents['c_velocitat_via'].value_counts(dropna=False)
# Out:
# 100.0    11954
# NaN       2642
# 999.0     1331
# 40.0      1072
# 50.0      1044
# 30.0       878
# 80.0       858
# 60.0       613
# 70.0       309
# 90.0       198
# 20.0       129
# 120.0       96
# 10.0        19
# 110.0       10
# 0.0          4
# 45.0         2
# 99.0         1
# 15.0         1
# Name: c_velocitat_via, dtype: int64

# %%
Accidents['c_velocitat_via']=Accidents['c_velocitat_via'].fillna('100').astype('int64')
Accidents['c_velocitat_via'].value_counts(dropna=False)
# Out:
# 100    14596
# 999     1331
# 40      1072
# 50      1044
# 30       878
# 80       858
# 60       613
# 70       309
# 90       198
# 20       129
# 120       96
# 10        19
# 110       10
# 0          4
# 45         2
# 99         1
# 15         1
# Name: c_velocitat_via, dtype: int64

# %%
def cleankSymbol(x):
    if x in [999]:
        return '100 or over'
    elif x<=20:
        return '20 or under'
    elif x<=60:
        return '20-60'
    else:
        return '60-100'
    
Accidents['c_velocitat_via'] = list(map(cleankSymbol, Accidents['c_velocitat_via']))

# %%
Accidents['c_velocitat_via'].value_counts(dropna=False)
# Out:
# 60-100         16068
# 20-60           3609
# 100 or over     1331
# 20 or under      153
# Name: c_velocitat_via, dtype: int64

# %% [markdown]
# # cleaning the NaN values column d_caract_entorn

# %%
Accidents['d_caract_entorn'].value_counts(dropna=False)
# Out:
# A nivell             8435
# Sense Especificar    7812
# Mixt                 2625
# Desmunt              1434
# Terraplé              823
# NaN                    32
# Name: d_caract_entorn, dtype: int64

# %%
Accidents['d_caract_entorn']=Accidents['d_caract_entorn'].fillna('Sense Especificar')

# %% [markdown]
# # cleaning the NaN values column d_caract_entorn

# %%
Accidents['d_carril_especial'].value_counts(dropna=False)
# Out:
# No n'hi ha                                      18567
# NaN                                              1349
# Carril bus                                        300
# Carril bici                                       184
# Carril acceleració                                158
# Altres                                            152
# Carril central                                    148
# Carril d'alentiment                                89
# Carril lent                                        79
# Carril avançament                                  42
# Habilitació voral/carril addicional                37
# Carril reversible                                  22
# Sense Especificar                                  21
# Carril habilitat en sentit contrari habitual       13
# Name: d_carril_especial, dtype: int64

# %%
Accidents['d_carril_especial']=Accidents['d_carril_especial'].fillna("No n'hi ha")

def cleankSymbol(x):
    if x in ["No n'hi ha"]:
        return 'No'
    elif x in ['Sense Especificar']:
        return 'No'
    else:
        return 'Si'
    
Accidents['d_carril_especial'] = list(map(cleankSymbol, Accidents['d_carril_especial']))
Accidents['d_carril_especial'].value_counts(dropna=False)
# Out:
# No    19937
# Si     1224
# Name: d_carril_especial, dtype: int64

# %% [markdown]
# # cleaning the NaN values column d_circulacio_mesures_esp

# %%
Accidents['d_circulacio_mesures_esp'].value_counts(dropna=False)
# Out:
# No n'hi ha                         20660
# Obres                                277
# Accident trànsit anterior             63
# Esdeveniment extraordinari            51
# Serveis de neteja o manteniment       43
# NaN                                   40
# Cons                                  14
# Control policial                      13
# Name: d_circulacio_mesures_esp, dtype: int64

# %%
Accidents['d_circulacio_mesures_esp']=Accidents['d_circulacio_mesures_esp'].fillna("No n'hi ha")

def cleankSymbol(x):
    if x in ["No n'hi ha"]:
        return 'No'
    else:
        return 'Si'
    
Accidents['d_circulacio_mesures_esp'] = list(map(cleankSymbol, Accidents['d_circulacio_mesures_esp']))
Accidents['d_circulacio_mesures_esp'].value_counts(dropna=False)
# Out:
# No    20700
# Si      461
# Name: d_circulacio_mesures_esp, dtype: int64

# %% [markdown]
# # cleaning the NaN values column d_regulacio_prioritat

# %%
Accidents['d_regulacio_prioritat'].value_counts(dropna=False)
# Out:
# NaN                                           14970
# Senyal Stop o cedeix pas                       2911
# Semàfor                                        1439
# Sols norma prioritat de pas                    1006
# Sols marques viàries (inclou pas vianants)      820
# Persona autoritzada                              11
# Altres                                            4
# Name: d_regulacio_prioritat, dtype: int64

# %%
Accidents['d_regulacio_prioritat']=Accidents['d_regulacio_prioritat'].fillna("NO")

def cleankSymbol(x):
    if x in ["NO"]:
        return 'No'
    else:
        return 'Si'
    
Accidents['d_regulacio_prioritat'] = list(map(cleankSymbol, Accidents['d_regulacio_prioritat']))
Accidents['d_regulacio_prioritat'].value_counts(dropna=False)
# Out:
# No    14970
# Si     6191
# Name: d_regulacio_prioritat, dtype: int64

# %% [markdown]
# # cleaning the NaN values column d_sentits_via

# %%
Accidents['d_sentits_via'].value_counts(dropna=False)
# Out:
# Doble sentit         12546
# Un sol sentit         4573
# NaN                   3496
# Sense especificar      546
# Name: d_sentits_via, dtype: int64

# %%
Accidents['d_sentits_via']=Accidents['d_sentits_via'].fillna('Doble sentit')

def cleankSymbol(x):
    if x in ['Sense especificar']:
        return 'Doble sentit'
    else:
        return x
    
Accidents['d_sentits_via'] = list(map(cleankSymbol, Accidents['d_sentits_via']))
Accidents['d_sentits_via'].value_counts(dropna=False)
# Out:
# Doble sentit     16588
# Un sol sentit     4573
# Name: d_sentits_via, dtype: int64

# %% [markdown]
# # cleaning the NaN values column d_subtipus_tram

# %%
Accidents['d_subtipus_tram'].value_counts(dropna=False)
# Out:
# NaN                                   14212
# Encreuament o intersecció en X o +     3131
# Intersecció en T o Y                   2153
# Giratòria                              1128
# Enllaç d'entrada o eixida               534
# Pas a nivell                              2
# Sense especificar                         1
# Name: d_subtipus_tram, dtype: int64

# %%
Accidents['d_subtipus_tram']=Accidents['d_subtipus_tram'].fillna('Recta')

def cleankSymbol(x):
    if x in ['Sense especificar']:
        return 'Recta'
    if x in ['Recta']:
        return 'Recta'
    else:
        return 'Encreuament o altres tipus'
    
Accidents['d_subtipus_tram'] = list(map(cleankSymbol, Accidents['d_subtipus_tram']))
Accidents['d_subtipus_tram'].value_counts(dropna=False)
# Out:
# Recta                         14213
# Encreuament o altres tipus     6948
# Name: d_subtipus_tram, dtype: int64

# %% [markdown]
# # cleaning the NaN values column d_titularitat_via

# %%
Accidents['d_titularitat_via'].value_counts(dropna=False)
# Out:
# NaN                  10712
# Autonòmica            3683
# Estatal               2269
# Provincial            1672
# Municipal             1463
# Altres                1348
# Sense Especificar       14
# Name: d_titularitat_via, dtype: int64

# %%
Accidents['d_titularitat_via']=Accidents['d_titularitat_via'].fillna('Sense Especificar')

# %% [markdown]
# # cleaning the NaN values column d_tracat_altimetric

# %%
Accidents['d_tracat_altimetric'].value_counts(dropna=False)
# Out:
# NaN                  7637
# Pla                  5203
# Sense especificar    4368
# Rampa o pendent      3707
# Canvi rasant          232
# Gual                   14
# Name: d_tracat_altimetric, dtype: int64

# %%
Accidents['d_tracat_altimetric']=Accidents['d_tracat_altimetric'].fillna('Sense especificar')

# %% [markdown]
# # Checking again the NaN values

# %%
nulls_percent_Accidents = pd.DataFrame(Accidents.isna().sum()/len(Accidents)).reset_index()
nulls_percent_Accidents.columns = ['column_name', 'nulls_percentage']
nulls_percent_Accidents[nulls_percent_Accidents['nulls_percentage']!=0]
# Out:
# Empty DataFrame
# Columns: [column_name, nulls_percentage]
# Index: []

# %% [markdown]
# # checking all the values

# %%
def df_values(Accidents):
    for i in range(0, len(Accidents.columns)):
        print('----------', Accidents.columns[i], '---------')
        print (Accidents.iloc[:,i].value_counts())
        print ('----------', Accidents.columns[i], '---------- \n')

df_values(Accidents)
# Out:
# ---------- any ---------
# 2010    1984
# 2012    1950
# 2014    1912
# 2013    1902
# 2015    1901
# 2011    1868
# 2016    1793
# 2018    1745
# 2019    1732
# 2017    1719
# 2021    1447
# 2020    1208
# Name: any, dtype: int64
# ---------- any ----------
#
# ---------- zona ---------
# Zona urbana    11542
# Carretera       9619
# Name: zona, dtype: int64
# ---------- zona ----------
#
# ---------- dat ---------
# 30/03/2012    17
# 15/05/2015    16
# 16/06/2018    16
# 22/12/2014    14
# 23/12/2011    14
#               ..
# 01/01/2018     1
# 01/10/2015     1
# 15/08/2018     1
# 07/01/2015     1
# 27/04/2021     1
# Name: dat, Length: 4308, dtype: int64
# ---------- dat ----------
#
# ---------- via ---------
# SE         11016
# N-II         480
# AP-7         429
# C-31         371
# CR           355
#            ...
# LV-3121        1
# TV-3032        1
# LV-5224        1
# BV-5202        1
# C-58c          1
# Name: via, Length: 737, dtype: int64
# ---------- via ----------
#
# ---------- pk ---------
# 0        11168
# 1          173
# 2           92
# 3           86
# 1,5         82
#          ...
# 256,2        1
# 743,9        1
# 58,1         1
# 134,2        1
# 63,5         1
# Name: pk, Length: 2802, dtype: int64
# ---------- pk ----------
#
# ---------- nommun ---------
# BARCELONA                   2750
# TERRASSA                     571
# SABADELL                     536
# LLEIDA                       514
# HOSPITALET DE LLOBREGAT      392
#                             ...
# MASLLOREN?                     1
# SANT JULIA DE CERDANYOLA       1
# CABANABONA                     1
# IVARS DE NOGUERA               1
# COMA I LA PEDRA, LA            1
# Name: nommun, Length: 877, dtype: int64
# ---------- nommun ----------
#
# ---------- nomcom ---------
# Barcelones           3752
# Valles Occidental    2330
# Baix Llobregat       1746
# Valles Oriental      1159
# Maresme              1021
# Segria                834
# Tarragones            725
# Alt Emporda           722
# Selva                 721
# Bages                 693
# Girones               660
# Baix Camp             634
# Osona                 629
# Alt Penedes           499
# Garraf                434
# Baix Emporda          408
# Anoia                 364
# Baix Ebre             354
# Baix Penedes          345
# Noguera               284
# Montsia               273
# Bergueda              234
# Alt Urgell            229
# Garrotxa              220
# Alt Camp              190
# Pla d'Urgell          149
# Cerdanya              147
# Pla de l'Estany       133
# Ribera d'Ebre         131
# Segarra               122
# Urgell                121
# Moianès               119
# Solsones              118
# Garrigues              99
# Conca de Barbera       89
# Pallars Jussa          87
# Ripolles               84
# Pallars Sobira         73
# Terra Alta             68
# Priorat                65
# Val d'Aran             61
# Alta Ribagorca         35
# Name: nomcom, dtype: int64
# ---------- nomcom ----------
#
# ---------- nomdem ---------
# Barcelona    12982
# Girona        3054
# Tarragona     2874
# Lleida        2251
# Name: nomdem, dtype: int64
# ---------- nomdem ----------
#
# ---------- f_morts ---------
# 0     18488
# 1      2477
# 2       153
# 3        29
# 4        10
# 5         2
# 13        1
# 7         1
# Name: f_morts, dtype: int64
# ---------- f_morts ----------
#
# ---------- f_ferits_greus ---------
# 1     17415
# 0      2121
# 2      1319
# 3       218
# 4        58
# 5        18
# 6         8
# 9         1
# 8         1
# 23        1
# 7         1
# Name: f_ferits_greus, dtype: int64
# ---------- f_ferits_greus ----------
#
# ---------- f_ferits_lleus ---------
# 0     16066
# 1      3420
# 2       900
# 3       411
# 4       191
# 5        85
# 6        34
# 7        22
# 9         7
# 8         5
# 12        4
# 11        3
# 10        3
# 13        2
# 18        2
# 14        2
# 21        1
# 22        1
# 17        1
# 25        1
# Name: f_ferits_lleus, dtype: int64
# ---------- f_ferits_lleus ----------
#
# ---------- f_victimes ---------
# 1     14855
# 2      3910
# 3      1214
# 4       576
# 5       306
# 6       148
# 7        59
# 8        41
# 9        13
# 10       11
# 11        7
# 12        5
# 13        4
# 14        3
# 24        2
# 20        1
# 15        1
# 49        1
# 18        1
# 16        1
# 23        1
# 26        1
# Name: f_victimes, dtype: int64
# ---------- f_victimes ----------
#
# ---------- f_unitats_implicades ---------
# 2     13276
# 1      5630
# 3      1673
# 4       359
# 5       129
# 6        47
# 7        22
# 8        12
# 9         5
# 12        2
# 21        1
# 15        1
# 10        1
# 13        1
# 11        1
# 19        1
# Name: f_unitats_implicades, dtype: int64
# ---------- f_unitats_implicades ----------
#
# ---------- f_vianants_implicades ---------
# 0     16460
# 1      4280
# 2       358
# 3        38
# 4        16
# 5         6
# 6         1
# 10        1
# 8         1
# Name: f_vianants_implicades, dtype: int64
# ---------- f_vianants_implicades ----------
#
# ---------- f_bicicletes_implicades ---------
# 0    19438
# 1     1593
# 2      101
# 3       16
# 4        6
# 5        4
# 7        1
# 6        1
# 8        1
# Name: f_bicicletes_implicades, dtype: int64
# ---------- f_bicicletes_implicades ----------
#
# ---------- f_ciclomotors_implicades ---------
# 0    19495
# 1     1639
# 2       25
# 5        1
# 3        1
# Name: f_ciclomotors_implicades, dtype: int64
# ---------- f_ciclomotors_implicades ----------
#
# ---------- f_motocicletes_implicades ---------
# 0    13103
# 1     7675
# 2      344
# 3       30
# 4        5
# 6        2
# 7        2
# Name: f_motocicletes_implicades, dtype: int64
# ---------- f_motocicletes_implicades ----------
#
# ---------- f_veh_lleugers_implicades ---------
# 1     12099
# 0      5911
# 2      2471
# 3       450
# 4       152
# 5        43
# 6        16
# 7        11
# 8         4
# 9         2
# 17        1
# 14        1
# Name: f_veh_lleugers_implicades, dtype: int64
# ---------- f_veh_lleugers_implicades ----------
#
# ---------- f_veh_pesants_implicades ---------
# 0     18783
# 1      2139
# 2       202
# 3        26
# 4         8
# 6         1
# 5         1
# 16        1
# Name: f_veh_pesants_implicades, dtype: int64
# ---------- f_veh_pesants_implicades ----------
#
# ---------- f_altres_unit_implicades ---------
# 0    20683
# 1      466
# 2       10
# 4        1
# 3        1
# Name: f_altres_unit_implicades, dtype: int64
# ---------- f_altres_unit_implicades ----------
#
# ---------- f_unit_desc_implicades ---------
# 0    21161
# Name: f_unit_desc_implicades, dtype: int64
# ---------- f_unit_desc_implicades ----------
#
# ---------- c_velocitat_via ---------
# 60-100         16068
# 20-60           3609
# 100 or over     1331
# 20 or under      153
# Name: c_velocitat_via, dtype: int64
# ---------- c_velocitat_via ----------
#
# ---------- d_acc_amb_fuga ---------
# No                   20569
# Si                     418
# Sense Especificar      174
# Name: d_acc_amb_fuga, dtype: int64
# ---------- d_acc_amb_fuga ----------
#
# ---------- d_boira ---------
# No n'hi ha    20132
# Si             1029
# Name: d_boira, dtype: int64
# ---------- d_boira ----------
#
# ---------- d_caract_entorn ---------
# A nivell             8435
# Sense Especificar    7844
# Mixt                 2625
# Desmunt              1434
# Terraplé              823
# Name: d_caract_entorn, dtype: int64
# ---------- d_caract_entorn ----------
#
# ---------- d_carril_especial ---------
# No    19937
# Si     1224
# Name: d_carril_especial, dtype: int64
# ---------- d_carril_especial ----------
#
# ---------- d_circulacio_mesures_esp ---------
# No    20700
# Si      461
# Name: d_circulacio_mesures_esp, dtype: int64
# ---------- d_circulacio_mesures_esp ----------
#
# ---------- d_climatologia ---------
# Bon temps            20003
# Pluja dèbil            883
# Pluja forta            250
# Nevant                  11
# Calamarsa               10
# Sense especificar        4
# Name: d_climatologia, dtype: int64
# ---------- d_climatologia ----------
#
# ---------- d_func_esp_via ---------
# Sense funció especial               20710
# Travessera                            306
# Ronda, cinturo o circumval.lacio       85
# Variant                                57
# Sense especificar                       3
# Name: d_func_esp_via, dtype: int64
# ---------- d_func_esp_via ----------
#
# ---------- d_gravetat ---------
# Accident greu      18488
# Accident mortal     2673
# Name: d_gravetat, dtype: int64
# ---------- d_gravetat ----------
#
# ---------- d_influit_boira ---------
# No                   18580
# Sense especificar     2545
# Si                      36
# Name: d_influit_boira, dtype: int64
# ---------- d_influit_boira ----------
#
# ---------- d_influit_caract_entorn ---------
# No                   20005
# Sense especificar      713
# Si                     443
# Name: d_influit_caract_entorn, dtype: int64
# ---------- d_influit_caract_entorn ----------
#
# ---------- d_influit_circulacio ---------
# No                   20858
# Si                     297
# Sense especificar        6
# Name: d_influit_circulacio, dtype: int64
# ---------- d_influit_circulacio ----------
#
# ---------- d_influit_estat_clima ---------
# No                   20670
# Si                     485
# Sense especificar        6
# Name: d_influit_estat_clima, dtype: int64
# ---------- d_influit_estat_clima ----------
#
# ---------- d_influit_inten_vent ---------
# No                   18621
# Sense especificar     2508
# Si                      32
# Name: d_influit_inten_vent, dtype: int64
# ---------- d_influit_inten_vent ----------
#
# ---------- d_influit_lluminositat ---------
# No                   20657
# Si                     498
# Sense especificar        6
# Name: d_influit_lluminositat, dtype: int64
# ---------- d_influit_lluminositat ----------
#
# ---------- d_influit_mesu_esp ---------
# No                   21065
# Si                      90
# Sense especificar        6
# Name: d_influit_mesu_esp, dtype: int64
# ---------- d_influit_mesu_esp ----------
#
# ---------- d_influit_obj_calcada ---------
# No                   20976
# Si                     179
# Sense especificar        6
# Name: d_influit_obj_calcada, dtype: int64
# ---------- d_influit_obj_calcada ----------
#
# ---------- d_influit_solcs_rases ---------
# No                   21073
# Si                      82
# Sense especificar        6
# Name: d_influit_solcs_rases, dtype: int64
# ---------- d_influit_solcs_rases ----------
#
# ---------- d_influit_visibilitat ---------
# No                   18939
# Sense especificar     1447
# Si                     775
# Name: d_influit_visibilitat, dtype: int64
# ---------- d_influit_visibilitat ----------
#
# ---------- d_inter_seccio ---------
# En secció                                 14164
# Dintre intersecció                         5855
# Arribant o eixint intersecció fins 50m     1142
# Name: d_inter_seccio, dtype: int64
# ---------- d_inter_seccio ----------
#
# ---------- d_limit_velocitat ---------
# Genérica via        15517
# Senyal velocitat     5644
# Name: d_limit_velocitat, dtype: int64
# ---------- d_limit_velocitat ----------
#
# ---------- d_lluminositat ---------
# De dia, dia clar                               14626
# De nit, il·luminació artificial suficient       2412
# De nit, sense llum artificial                   1431
# Alba o capvespre                                 993
# De nit, il·luminació artificial insuficient      867
# De dia, dia fosc                                 826
# Sense especificar                                  6
# Name: d_lluminositat, dtype: int64
# ---------- d_lluminositat ----------
#
# ---------- d_regulacio_prioritat ---------
# No    14970
# Si     6191
# Name: d_regulacio_prioritat, dtype: int64
# ---------- d_regulacio_prioritat ----------
#
# ---------- d_sentits_via ---------
# Doble sentit     16588
# Un sol sentit     4573
# Name: d_sentits_via, dtype: int64
# ---------- d_sentits_via ----------
#
# ---------- d_subtipus_accident ---------
# Atropellament                                              4566
# Envestida (frontal lateral)                                4016
# Resta sortides de via                                      2444
# Caiguda en la via                                          2016
# Fregament o col·lisió lateral                              1909
# Col·lisió frontal                                          1847
# Encalç                                                     1695
# Xoc contra objecte/obstacle sense sortida prèvia de via    1165
# Altres                                                     1095
# Sortida de via amb xoc o col·lisió                          283
# Sortida de via amb bolcada                                   76
# Xoc amb animal a la calçada                                  39
# Sortida de via amb atropellament                             10
# Name: d_subtipus_accident, dtype: int64
# ---------- d_subtipus_accident ----------
#
# ---------- d_subtipus_tram ---------
# Recta                         14213
# Encreuament o altres tipus     6948
# Name: d_subtipus_tram, dtype: int64
# ---------- d_subtipus_tram ----------
#
# ---------- d_subzona ---------
# Zona urbana    10560
# Carretera       9619
# Travessera       982
# Name: d_subzona, dtype: int64
# ---------- d_subzona ----------
#
# ---------- d_superficie ---------
# Sec i net            20078
# Mullat                 793
# Relliscós              140
# Inundat                114
# Gelat                   22
# Nevat                   10
# Sense especificar        4
# Name: d_superficie, dtype: int64
# ---------- d_superficie ----------
#
# ---------- d_tipus_via ---------
# Via urbana( inclou carrer i carrer residencial)    10676
# Carretera convencional                              9019
# Altres                                               579
# Autovia                                              491
# Autopista                                            221
# Camí rural/pista forestal                            175
# Name: d_tipus_via, dtype: int64
# ---------- d_tipus_via ----------
#
# ---------- d_titularitat_via ---------
# Sense Especificar    10726
# Autonòmica            3683
# Estatal               2269
# Provincial            1672
# Municipal             1463
# Altres                1348
# Name: d_titularitat_via, dtype: int64
# ---------- d_titularitat_via ----------
#
# ---------- d_tracat_altimetric ---------
# Sense especificar    12005
# Pla                   5203
# Rampa o pendent       3707
# Canvi rasant           232
# Gual                    14
# Name: d_tracat_altimetric, dtype: int64
# ---------- d_tracat_altimetric ----------
#
# ---------- d_vent ---------
# Calma, vent molt suau    20762
# Vent moderat               310
# Vent fort                   83
# Sense especificar            6
# Name: d_vent, dtype: int64
# ---------- d_vent ----------
#
# ---------- grupdialab ---------
# Feiners         13441
# CapDeSetmana     7720
# Name: grupdialab, dtype: int64
# ---------- grupdialab ----------
#
# ---------- hor ---------
# 18,3    125
# 20      120
# 19,3    117
# 12      115
# 18      108
#        ...
# 5,12      1
# 1,41      1
# 3,26      1
# 4,06      1
# 4,16      1
# Name: hor, Length: 1411, dtype: int64
# ---------- hor ----------
#
# ---------- gruphor ---------
# Tarda    9935
# Matí     8661
# Nit      2565
# Name: gruphor, dtype: int64
# ---------- gruphor ----------
#
# ---------- tipacc ---------
# Col.lisió de vehicles en marxa                             9467
# Atropellament                                              4566
# Sortida de la calcada sense especificar                    2813
# Bolcada a la calcada                                       2016
# Col.lisió d'un vehicle contra un obstacle de la calcada    1204
# Altres                                                     1095
# Name: tipacc, dtype: int64
# ---------- tipacc ----------
#
# ---------- tipdia ---------
# dill-dij    11733
# div          3317
# dis          3196
# dg           2915
# Name: tipdia, dtype: int64
# ---------- tipdia ----------

# %% [markdown]
# # checking the date column

# %%
Accidents['dat'].value_counts(dropna=False)
# Out:
# 30/03/2012    17
# 15/05/2015    16
# 16/06/2018    16
# 22/12/2014    14
# 23/12/2011    14
#               ..
# 01/01/2018     1
# 01/10/2015     1
# 15/08/2018     1
# 07/01/2015     1
# 27/04/2021     1
# Name: dat, Length: 4308, dtype: int64

# %%
Accidents['data'] = pd.to_datetime(Accidents['dat'], errors='coerce')
# Out:
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/01/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/05/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/08/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/08/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/01/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/06/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/06/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/05/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/12/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/06/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/09/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/03/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/08/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31/12/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/05/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/08/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/06/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/01/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/09/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/02/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/04/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/09/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/04/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/03/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/01/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/01/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31/01/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/05/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/08/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/03/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/06/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/04/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/04/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/09/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/05/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/04/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/05/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/03/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/02/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/08/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/05/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/05/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/01/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/05/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/01/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/03/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/12/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/01/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/09/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/03/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/03/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/09/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/03/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/03/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/08/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/06/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/01/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/01/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/01/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/03/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/04/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/09/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/04/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/05/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/03/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/05/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/09/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/08/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/04/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/03/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/09/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/01/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/04/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/06/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/09/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/02/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/06/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/03/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/12/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/12/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/08/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/04/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/08/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/06/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/05/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/03/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/04/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/12/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/12/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/08/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/02/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/02/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/02/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/02/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/09/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/04/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/05/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/05/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/12/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/02/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/03/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31/03/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/09/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/06/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/01/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/04/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/04/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/06/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31/08/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/05/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/04/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/12/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/01/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/12/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/01/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/09/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/09/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/03/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31/05/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/04/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/02/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/03/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/12/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/06/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/12/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/02/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/07/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/06/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/02/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/02/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/11/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/05/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/05/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/07/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/09/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/05/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31/05/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/09/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/07/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/04/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/05/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/11/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/09/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/09/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/02/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/06/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/02/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/04/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/02/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/04/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/01/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/02/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31/01/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/02/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/06/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/04/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/06/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/05/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/04/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/07/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/04/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\joanv\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/04/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)

# %%
Accidents['data'].value_counts(dropna=False)
# Out:
# 2012-03-30    17
# 2015-05-15    16
# 2018-06-16    16
# 2014-12-22    14
# 2011-12-23    14
#               ..
# 2018-01-01     1
# 2015-01-10     1
# 2018-08-15     1
# 2015-07-01     1
# 2021-04-27     1
# Name: data, Length: 4308, dtype: int64

# %% [markdown]
# # creating new columns indicating month, year, weekdayname

# %%
Accidents['year'] = Accidents['data'].dt.year
Accidents['month'] = Accidents['data'].dt.month
Accidents['weekday'] = Accidents['data'].dt.weekday
Accidents['day_name'] = Accidents['data'].dt.day_name()

# %% [markdown]
# # drop the old date columns and other columns

# %%
drop_list=[]
drop_list =drop_list +['f_unit_desc_implicades','any','dat','data']
drop_list
# Out:
# ['f_unit_desc_implicades', 'any', 'dat', 'data']

# %% [markdown]
# # changing the values in NO or YES

# %%
def cleanYesNOT(x):
    if x>0:
        return 'No'
    else:
        return 'Si'
    
Accidents['f_morts'] = list(map(cleanYesNOT, Accidents['f_morts']))
Accidents['f_ferits_greus'] = list(map(cleanYesNOT, Accidents['f_ferits_greus']))
Accidents['f_ferits_lleus'] = list(map(cleanYesNOT, Accidents['f_ferits_lleus']))
Accidents['f_victimes'] = list(map(cleanYesNOT, Accidents['f_victimes']))
Accidents['f_vianants_implicades'] = list(map(cleanYesNOT, Accidents['f_vianants_implicades']))
Accidents['f_ciclomotors_implicades'] = list(map(cleanYesNOT, Accidents['f_ciclomotors_implicades']))
Accidents['f_motocicletes_implicades'] = list(map(cleanYesNOT, Accidents['f_motocicletes_implicades']))
Accidents['f_veh_lleugers_implicades'] = list(map(cleanYesNOT, Accidents['f_veh_lleugers_implicades']))
Accidents['f_veh_pesants_implicades'] = list(map(cleanYesNOT, Accidents['f_veh_pesants_implicades']))
Accidents['f_altres_unit_implicades'] = list(map(cleanYesNOT, Accidents['f_altres_unit_implicades']))

# %% [markdown]
# # changing the values in 0 or 1 in case of the target = 'f_bicicletes_implicades'

# %%
def cleanYesNOT(x):
    if x>0:
        return 1
    else:
        return 0
    
Accidents['f_bicicletes_implicades'] = list(map(cleanYesNOT, Accidents['f_bicicletes_implicades']))

# %%
Accidents['d_boira'].value_counts(dropna=False)
# Out:
# No n'hi ha    20132
# Si             1029
# Name: d_boira, dtype: int64

# %% [markdown]
# # Changing the values in d_boira

# %%
def cleankSymbol(x):
    if x in ["No n'hi ha"]:
        return 'No'
    else:
        return x
    
Accidents['d_boira'] = list(map(cleankSymbol, Accidents['d_boira']))
Accidents['d_boira'].value_counts(dropna=False)
# Out:
# No    20132
# Si     1029
# Name: d_boira, dtype: int64

# %% [markdown]
# # Cleaning the undetermineted values

# %%
def cleankSymbol(x):
    if x in ["Sense Especificar"]:
        return 'No'
    else:
        return x
    
Accidents['d_acc_amb_fuga'] = list(map(cleankSymbol, Accidents['d_acc_amb_fuga']))
Accidents['d_climatologia'] = list(map(cleankSymbol, Accidents['d_climatologia']))
Accidents['d_func_esp_via'] = list(map(cleankSymbol, Accidents['d_func_esp_via']))

# %%
def cleankSymbol(x):
    if x in ["Sense especificar"]:
        return 'No'
    else:
        return x

Accidents['d_influit_boira'] = list(map(cleankSymbol, Accidents['d_influit_boira']))
Accidents['d_influit_caract_entorn'] = list(map(cleankSymbol, Accidents['d_influit_caract_entorn']))
Accidents['d_influit_circulacio'] = list(map(cleankSymbol, Accidents['d_influit_circulacio']))
Accidents['d_influit_estat_clima'] = list(map(cleankSymbol, Accidents['d_influit_estat_clima']))
Accidents['d_influit_inten_vent'] = list(map(cleankSymbol, Accidents['d_influit_inten_vent']))
Accidents['d_influit_lluminositat'] = list(map(cleankSymbol, Accidents['d_influit_lluminositat']))
Accidents['d_influit_mesu_esp'] = list(map(cleankSymbol, Accidents['d_influit_mesu_esp']))
Accidents['d_influit_obj_calcada'] = list(map(cleankSymbol, Accidents['d_influit_obj_calcada']))
Accidents['d_influit_solcs_rases'] = list(map(cleankSymbol, Accidents['d_influit_solcs_rases']))
Accidents['d_influit_visibilitat'] = list(map(cleankSymbol, Accidents['d_influit_visibilitat']))

# %% [markdown]
# # Getting just 2 values in d_climatologia, d_func_esp_via, d_vent

# %%
def cleankSymbol(x):
    if x in ["Bon temps"]:
        return 'Bon temps'
    else:
        return 'Mal temps'
    
Accidents['d_climatologia'] = list(map(cleankSymbol, Accidents['d_climatologia']))
Accidents['d_climatologia'].value_counts(dropna=False)
# Out:
# Bon temps    20003
# Mal temps     1158
# Name: d_climatologia, dtype: int64

# %%
def cleankSymbol(x):
    if x in ["Sense funció especial"]:
        return 'Via normal'
    else:
        return 'Via especial'
    
Accidents['d_func_esp_via'] = list(map(cleankSymbol, Accidents['d_func_esp_via']))
Accidents['d_func_esp_via'].value_counts(dropna=False)
# Out:
# Via normal      20710
# Via especial      451
# Name: d_func_esp_via, dtype: int64

# %%
def cleankSymbol(x):
    if x in ["Sense especificar","Calma, vent molt suau"]:
        return 'No'
    else:
        return 'Si'
    
Accidents['d_vent'] = list(map(cleankSymbol, Accidents['d_vent']))
Accidents['d_vent'].value_counts(dropna=False)
# Out:
# No    20768
# Si      393
# Name: d_vent, dtype: int64

# %% [markdown]
# # Grouping the minority values in d_subtipus_accident and d_lluminositat

# %%
def cleankSymbol(x):
    if x in ["Sortida de via amb xoc o col·lisió","Sortida de via amb bolcada","Xoc amb animal a la calçada","Sortida de via amb atropellament"]:
        return 'Altres'
    else:
        return x
    
Accidents['d_subtipus_accident'] = list(map(cleankSymbol, Accidents['d_subtipus_accident']))
Accidents['d_subtipus_accident'].value_counts(dropna=False)
# Out:
# Atropellament                                              4566
# Envestida (frontal lateral)                                4016
# Resta sortides de via                                      2444
# Caiguda en la via                                          2016
# Fregament o col·lisió lateral                              1909
# Col·lisió frontal                                          1847
# Encalç                                                     1695
# Altres                                                     1503
# Xoc contra objecte/obstacle sense sortida prèvia de via    1165
# Name: d_subtipus_accident, dtype: int64

# %%
def cleankSymbol(x):
    if x in ["Sense especificar"]:
        return "De dia, dia clar"
    else:
        return x
    
Accidents['d_lluminositat'] = list(map(cleankSymbol, Accidents['d_lluminositat']))
Accidents['d_lluminositat'].value_counts(dropna=False)
# Out:
# De dia, dia clar                               14632
# De nit, il·luminació artificial suficient       2412
# De nit, sense llum artificial                   1431
# Alba o capvespre                                 993
# De nit, il·luminació artificial insuficient      867
# De dia, dia fosc                                 826
# Name: d_lluminositat, dtype: int64

# %% [markdown]
# # Getting just 2 values in d_superficie

# %%
def cleankSymbol(x):
    if x in ["Sec i net","Sense especificar"]:
        return 'Sec i net'
    else:
        return 'Mullat o altres condicions'
    
Accidents['d_superficie'] = list(map(cleankSymbol, Accidents['d_superficie']))
Accidents['d_superficie'].value_counts(dropna=False)
# Out:
# Sec i net                     20082
# Mullat o altres condicions     1079
# Name: d_superficie, dtype: int64

# %% [markdown]
# # Cheacking all values for each feature

# %%
def df_values(Accidents):
    for i in range(0, len(Accidents.columns)):
        print('----------', Accidents.columns[i], '---------')
        print (Accidents.iloc[:,i].value_counts())
        print ('----------', Accidents.columns[i], '---------- \n')

df_values(Accidents)
# Out:
# ---------- any ---------
# 2010    1984
# 2012    1950
# 2014    1912
# 2013    1902
# 2015    1901
# 2011    1868
# 2016    1793
# 2018    1745
# 2019    1732
# 2017    1719
# 2021    1447
# 2020    1208
# Name: any, dtype: int64
# ---------- any ----------
#
# ---------- zona ---------
# Zona urbana    11542
# Carretera       9619
# Name: zona, dtype: int64
# ---------- zona ----------
#
# ---------- dat ---------
# 30/03/2012    17
# 15/05/2015    16
# 16/06/2018    16
# 22/12/2014    14
# 23/12/2011    14
#               ..
# 01/01/2018     1
# 01/10/2015     1
# 15/08/2018     1
# 07/01/2015     1
# 27/04/2021     1
# Name: dat, Length: 4308, dtype: int64
# ---------- dat ----------
#
# ---------- via ---------
# SE         11016
# N-II         480
# AP-7         429
# C-31         371
# CR           355
#            ...
# LV-3121        1
# TV-3032        1
# LV-5224        1
# BV-5202        1
# C-58c          1
# Name: via, Length: 737, dtype: int64
# ---------- via ----------
#
# ---------- pk ---------
# 0        11168
# 1          173
# 2           92
# 3           86
# 1,5         82
#          ...
# 256,2        1
# 743,9        1
# 58,1         1
# 134,2        1
# 63,5         1
# Name: pk, Length: 2802, dtype: int64
# ---------- pk ----------
#
# ---------- nommun ---------
# BARCELONA                   2750
# TERRASSA                     571
# SABADELL                     536
# LLEIDA                       514
# HOSPITALET DE LLOBREGAT      392
#                             ...
# MASLLOREN?                     1
# SANT JULIA DE CERDANYOLA       1
# CABANABONA                     1
# IVARS DE NOGUERA               1
# COMA I LA PEDRA, LA            1
# Name: nommun, Length: 877, dtype: int64
# ---------- nommun ----------
#
# ---------- nomcom ---------
# Barcelones           3752
# Valles Occidental    2330
# Baix Llobregat       1746
# Valles Oriental      1159
# Maresme              1021
# Segria                834
# Tarragones            725
# Alt Emporda           722
# Selva                 721
# Bages                 693
# Girones               660
# Baix Camp             634
# Osona                 629
# Alt Penedes           499
# Garraf                434
# Baix Emporda          408
# Anoia                 364
# Baix Ebre             354
# Baix Penedes          345
# Noguera               284
# Montsia               273
# Bergueda              234
# Alt Urgell            229
# Garrotxa              220
# Alt Camp              190
# Pla d'Urgell          149
# Cerdanya              147
# Pla de l'Estany       133
# Ribera d'Ebre         131
# Segarra               122
# Urgell                121
# Moianès               119
# Solsones              118
# Garrigues              99
# Conca de Barbera       89
# Pallars Jussa          87
# Ripolles               84
# Pallars Sobira         73
# Terra Alta             68
# Priorat                65
# Val d'Aran             61
# Alta Ribagorca         35
# Name: nomcom, dtype: int64
# ---------- nomcom ----------
#
# ---------- nomdem ---------
# Barcelona    12982
# Girona        3054
# Tarragona     2874
# Lleida        2251
# Name: nomdem, dtype: int64
# ---------- nomdem ----------
#
# ---------- f_morts ---------
# Si    18488
# No     2673
# Name: f_morts, dtype: int64
# ---------- f_morts ----------
#
# ---------- f_ferits_greus ---------
# No    19040
# Si     2121
# Name: f_ferits_greus, dtype: int64
# ---------- f_ferits_greus ----------
#
# ---------- f_ferits_lleus ---------
# Si    16066
# No     5095
# Name: f_ferits_lleus, dtype: int64
# ---------- f_ferits_lleus ----------
#
# ---------- f_victimes ---------
# No    21161
# Name: f_victimes, dtype: int64
# ---------- f_victimes ----------
#
# ---------- f_unitats_implicades ---------
# 2     13276
# 1      5630
# 3      1673
# 4       359
# 5       129
# 6        47
# 7        22
# 8        12
# 9         5
# 12        2
# 21        1
# 15        1
# 10        1
# 13        1
# 11        1
# 19        1
# Name: f_unitats_implicades, dtype: int64
# ---------- f_unitats_implicades ----------
#
# ---------- f_vianants_implicades ---------
# Si    16460
# No     4701
# Name: f_vianants_implicades, dtype: int64
# ---------- f_vianants_implicades ----------
#
# ---------- f_bicicletes_implicades ---------
# 0    19438
# 1     1723
# Name: f_bicicletes_implicades, dtype: int64
# ---------- f_bicicletes_implicades ----------
#
# ---------- f_ciclomotors_implicades ---------
# Si    19495
# No     1666
# Name: f_ciclomotors_implicades, dtype: int64
# ---------- f_ciclomotors_implicades ----------
#
# ---------- f_motocicletes_implicades ---------
# Si    13103
# No     8058
# Name: f_motocicletes_implicades, dtype: int64
# ---------- f_motocicletes_implicades ----------
#
# ---------- f_veh_lleugers_implicades ---------
# No    15250
# Si     5911
# Name: f_veh_lleugers_implicades, dtype: int64
# ---------- f_veh_lleugers_implicades ----------
#
# ---------- f_veh_pesants_implicades ---------
# Si    18783
# No     2378
# Name: f_veh_pesants_implicades, dtype: int64
# ---------- f_veh_pesants_implicades ----------
#
# ---------- f_altres_unit_implicades ---------
# Si    20683
# No      478
# Name: f_altres_unit_implicades, dtype: int64
# ---------- f_altres_unit_implicades ----------
#
# ---------- f_unit_desc_implicades ---------
# 0    21161
# Name: f_unit_desc_implicades, dtype: int64
# ---------- f_unit_desc_implicades ----------
#
# ---------- c_velocitat_via ---------
# 60-100         16068
# 20-60           3609
# 100 or over     1331
# 20 or under      153
# Name: c_velocitat_via, dtype: int64
# ---------- c_velocitat_via ----------
#
# ---------- d_acc_amb_fuga ---------
# No    20743
# Si      418
# Name: d_acc_amb_fuga, dtype: int64
# ---------- d_acc_amb_fuga ----------
#
# ---------- d_boira ---------
# No    20132
# Si     1029
# Name: d_boira, dtype: int64
# ---------- d_boira ----------
#
# ---------- d_caract_entorn ---------
# A nivell             8435
# Sense Especificar    7844
# Mixt                 2625
# Desmunt              1434
# Terraplé              823
# Name: d_caract_entorn, dtype: int64
# ---------- d_caract_entorn ----------
#
# ---------- d_carril_especial ---------
# No    19937
# Si     1224
# Name: d_carril_especial, dtype: int64
# ---------- d_carril_especial ----------
#
# ---------- d_circulacio_mesures_esp ---------
# No    20700
# Si      461
# Name: d_circulacio_mesures_esp, dtype: int64
# ---------- d_circulacio_mesures_esp ----------
#
# ---------- d_climatologia ---------
# Bon temps    20003
# Mal temps     1158
# Name: d_climatologia, dtype: int64
# ---------- d_climatologia ----------
#
# ---------- d_func_esp_via ---------
# Via normal      20710
# Via especial      451
# Name: d_func_esp_via, dtype: int64
# ---------- d_func_esp_via ----------
#
# ---------- d_gravetat ---------
# Accident greu      18488
# Accident mortal     2673
# Name: d_gravetat, dtype: int64
# ---------- d_gravetat ----------
#
# ---------- d_influit_boira ---------
# No    21125
# Si       36
# Name: d_influit_boira, dtype: int64
# ---------- d_influit_boira ----------
#
# ---------- d_influit_caract_entorn ---------
# No    20718
# Si      443
# Name: d_influit_caract_entorn, dtype: int64
# ---------- d_influit_caract_entorn ----------
#
# ---------- d_influit_circulacio ---------
# No    20864
# Si      297
# Name: d_influit_circulacio, dtype: int64
# ---------- d_influit_circulacio ----------
#
# ---------- d_influit_estat_clima ---------
# No    20676
# Si      485
# Name: d_influit_estat_clima, dtype: int64
# ---------- d_influit_estat_clima ----------
#
# ---------- d_influit_inten_vent ---------
# No    21129
# Si       32
# Name: d_influit_inten_vent, dtype: int64
# ---------- d_influit_inten_vent ----------
#
# ---------- d_influit_lluminositat ---------
# No    20663
# Si      498
# Name: d_influit_lluminositat, dtype: int64
# ---------- d_influit_lluminositat ----------
#
# ---------- d_influit_mesu_esp ---------
# No    21071
# Si       90
# Name: d_influit_mesu_esp, dtype: int64
# ---------- d_influit_mesu_esp ----------
#
# ---------- d_influit_obj_calcada ---------
# No    20982
# Si      179
# Name: d_influit_obj_calcada, dtype: int64
# ---------- d_influit_obj_calcada ----------
#
# ---------- d_influit_solcs_rases ---------
# No    21079
# Si       82
# Name: d_influit_solcs_rases, dtype: int64
# ---------- d_influit_solcs_rases ----------
#
# ---------- d_influit_visibilitat ---------
# No    20386
# Si      775
# Name: d_influit_visibilitat, dtype: int64
# ---------- d_influit_visibilitat ----------
#
# ---------- d_inter_seccio ---------
# En secció                                 14164
# Dintre intersecció                         5855
# Arribant o eixint intersecció fins 50m     1142
# Name: d_inter_seccio, dtype: int64
# ---------- d_inter_seccio ----------
#
# ---------- d_limit_velocitat ---------
# Genérica via        15517
# Senyal velocitat     5644
# Name: d_limit_velocitat, dtype: int64
# ---------- d_limit_velocitat ----------
#
# ---------- d_lluminositat ---------
# De dia, dia clar                               14632
# De nit, il·luminació artificial suficient       2412
# De nit, sense llum artificial                   1431
# Alba o capvespre                                 993
# De nit, il·luminació artificial insuficient      867
# De dia, dia fosc                                 826
# Name: d_lluminositat, dtype: int64
# ---------- d_lluminositat ----------
#
# ---------- d_regulacio_prioritat ---------
# No    14970
# Si     6191
# Name: d_regulacio_prioritat, dtype: int64
# ---------- d_regulacio_prioritat ----------
#
# ---------- d_sentits_via ---------
# Doble sentit     16588
# Un sol sentit     4573
# Name: d_sentits_via, dtype: int64
# ---------- d_sentits_via ----------
#
# ---------- d_subtipus_accident ---------
# Atropellament                                              4566
# Envestida (frontal lateral)                                4016
# Resta sortides de via                                      2444
# Caiguda en la via                                          2016
# Fregament o col·lisió lateral                              1909
# Col·lisió frontal                                          1847
# Encalç                                                     1695
# Altres                                                     1503
# Xoc contra objecte/obstacle sense sortida prèvia de via    1165
# Name: d_subtipus_accident, dtype: int64
# ---------- d_subtipus_accident ----------
#
# ---------- d_subtipus_tram ---------
# Recta                         14213
# Encreuament o altres tipus     6948
# Name: d_subtipus_tram, dtype: int64
# ---------- d_subtipus_tram ----------
#
# ---------- d_subzona ---------
# Zona urbana    10560
# Carretera       9619
# Travessera       982
# Name: d_subzona, dtype: int64
# ---------- d_subzona ----------
#
# ---------- d_superficie ---------
# Sec i net                     20082
# Mullat o altres condicions     1079
# Name: d_superficie, dtype: int64
# ---------- d_superficie ----------
#
# ---------- d_tipus_via ---------
# Via urbana( inclou carrer i carrer residencial)    10676
# Carretera convencional                              9019
# Altres                                               579
# Autovia                                              491
# Autopista                                            221
# Camí rural/pista forestal                            175
# Name: d_tipus_via, dtype: int64
# ---------- d_tipus_via ----------
#
# ---------- d_titularitat_via ---------
# Sense Especificar    10726
# Autonòmica            3683
# Estatal               2269
# Provincial            1672
# Municipal             1463
# Altres                1348
# Name: d_titularitat_via, dtype: int64
# ---------- d_titularitat_via ----------
#
# ---------- d_tracat_altimetric ---------
# Sense especificar    12005
# Pla                   5203
# Rampa o pendent       3707
# Canvi rasant           232
# Gual                    14
# Name: d_tracat_altimetric, dtype: int64
# ---------- d_tracat_altimetric ----------
#
# ---------- d_vent ---------
# No    20768
# Si      393
# Name: d_vent, dtype: int64
# ---------- d_vent ----------
#
# ---------- grupdialab ---------
# Feiners         13441
# CapDeSetmana     7720
# Name: grupdialab, dtype: int64
# ---------- grupdialab ----------
#
# ---------- hor ---------
# 18,3    125
# 20      120
# 19,3    117
# 12      115
# 18      108
#        ...
# 5,12      1
# 1,41      1
# 3,26      1
# 4,06      1
# 4,16      1
# Name: hor, Length: 1411, dtype: int64
# ---------- hor ----------
#
# ---------- gruphor ---------
# Tarda    9935
# Matí     8661
# Nit      2565
# Name: gruphor, dtype: int64
# ---------- gruphor ----------
#
# ---------- tipacc ---------
# Col.lisió de vehicles en marxa                             9467
# Atropellament                                              4566
# Sortida de la calcada sense especificar                    2813
# Bolcada a la calcada                                       2016
# Col.lisió d'un vehicle contra un obstacle de la calcada    1204
# Altres                                                     1095
# Name: tipacc, dtype: int64
# ---------- tipacc ----------
#
# ---------- tipdia ---------
# dill-dij    11733
# div          3317
# dis          3196
# dg           2915
# Name: tipdia, dtype: int64
# ---------- tipdia ----------
#
# ---------- data ---------
# 2012-03-30    17
# 2015-05-15    16
# 2018-06-16    16
# 2014-12-22    14
# 2011-12-23    14
#               ..
# 2018-01-01     1
# 2015-01-10     1
# 2018-08-15     1
# 2015-07-01     1
# 2021-04-27     1
# Name: data, Length: 4308, dtype: int64
# ---------- data ----------
#
# ---------- year ---------
# 2010    1984
# 2012    1950
# 2014    1912
# 2013    1902
# 2015    1901
# 2011    1868
# 2016    1793
# 2018    1745
# 2019    1732
# 2017    1719
# 2021    1447
# 2020    1208
# Name: year, dtype: int64
# ---------- year ----------
#
# ---------- month ---------
# 7     1945
# 10    1925
# 5     1921
# 6     1851
# 9     1791
# 11    1742
# 3     1735
# 8     1718
# 1     1681
# 12    1666
# 4     1646
# 2     1540
# Name: month, dtype: int64
# ---------- month ----------
#
# ---------- weekday ---------
# 4    3226
# 5    3181
# 3    3089
# 6    2961
# 1    2940
# 2    2887
# 0    2877
# Name: weekday, dtype: int64
# ---------- weekday ----------
#
# ---------- day_name ---------
# Friday       3226
# Saturday     3181
# Thursday     3089
# Sunday       2961
# Tuesday      2940
# Wednesday    2887
# Monday       2877
# Name: day_name, dtype: int64
# ---------- day_name ----------

# %% [markdown]
# # Dropping features with same information than others

# %%
drop_list =drop_list +['f_victimes','tipdia']
drop_list
# Out:
# ['f_unit_desc_implicades', 'any', 'dat', 'data', 'f_victimes', 'tipdia']

# %%
Accidents_cleaned=Accidents.drop(drop_list, axis = 1)

# %%
pd.set_option("display.max_columns", None)
Accidents_cleaned.head(60)
# Out:
#            zona      via     pk                    nommun             nomcom  \
# 0   Zona urbana       SE      0         CANOVES I SAMALUS    Valles Oriental
# 1     Carretera    N-240   99,9                    LLEIDA             Segria
# 2     Carretera     N-II  708,7      FORNELLS DE LA SELVA            Girones
# 3   Zona urbana       SE      0                 BARCELONA         Barcelones
# 4   Zona urbana       SE      0                  BADALONA         Barcelones
# 5     Carretera       SE      0  SANT CARLES DE LA RAPITA            Montsia
# 6   Zona urbana       SE      0                 BARCELONA         Barcelones
# 7   Zona urbana       SE      0                 BARCELONA         Barcelones
# 8     Carretera     AP-7    138         MOLLET DEL VALLES    Valles Oriental
# 9     Carretera       SE      0     CERDANYOLA DEL VALLES  Valles Occidental
# 10  Zona urbana     C-31    350      TORROELLA DE MONTGRI       Baix Emporda
# 11  Zona urbana       SE      0                     ODENA              Anoia
# 12    Carretera     N-II  719,4                    GIRONA            Girones
# 13  Zona urbana       SE      0                 BARCELONA         Barcelones
# 14  Zona urbana       SE      0                      REUS          Baix Camp
# 15  Zona urbana       SE      0                      OLOT           Garrotxa
# 16  Zona urbana       SE      0                    LLEIDA             Segria
# 17    Carretera    B-522    6,1                   MANLLEU              Osona
# 18  Zona urbana       SE      0                 BARCELONA         Barcelones
# 19    Carretera     C-14  162,8                   ORGANYA         Alt Urgell
# 20    Carretera   GI-673    1,5       CALDES DE MALAVELLA              Selva
# 21    Carretera  LV-3021      1           ARTESA DE SEGRE            Noguera
# 22  Zona urbana       SE      0                 MARTORELL     Baix Llobregat
# 23    Carretera     C-17   39,5                TAGAMANENT    Valles Oriental
# 24  Zona urbana       SE      0                  TERRASSA  Valles Occidental
# 25  Zona urbana       SE      0         MOLLET DEL VALLES    Valles Oriental
# 26    Carretera       SE      0      PRAT DE LLOBREGAT, E     Baix Llobregat
# 27  Zona urbana       SE      0               FULIOLA, LA             Urgell
# 28  Zona urbana       SE      0                 BARCELONA         Barcelones
# 29  Zona urbana       SE      0                   MANRESA              Bages
# 30  Zona urbana       SE      0                  ROQUETES          Baix Ebre
# 31  Zona urbana  TP-7225    8,1                MORELL, EL         Tarragones
# 32  Zona urbana       SE      0                 BARCELONA         Barcelones
# 33    Carretera       AL    3,3                 BARCELONA         Barcelones
# 34    Carretera  C-1415B    8,4             LLICA D'AMUNT    Valles Oriental
# 35  Zona urbana       SE      0                 BARCELONA         Barcelones
# 36    Carretera     C-55   10,7                  COLLBATO     Baix Llobregat
# 37  Zona urbana       SE      0                  TERRASSA  Valles Occidental
# 38  Zona urbana       SE      0                    GIRONA            Girones
# 39    Carretera  BP-2121    8,2        SANT MARTI SARROCA        Alt Penedes
# 40  Zona urbana       SE      0                    ALELLA            Maresme
# 41  Zona urbana       SE      0     CORNELLA DE LLOBREGAT     Baix Llobregat
# 42    Carretera     C-31  137,4                  CALAFELL       Baix Penedes
# 43  Zona urbana       SE      0                 BARCELONA         Barcelones
# 44    Carretera     N-II  661,9           SANT POL DE MAR            Maresme
# 45    Carretera       SE      0       TORROELLA DE FLUVIA        Alt Emporda
# 46  Zona urbana       SE      0                  VIDRERES              Selva
# 47    Carretera  TV-3405    8,5                   AMPOSTA            Montsia
# 48  Zona urbana       SE      0     SANT BOI DE LLOBREGAT     Baix Llobregat
# 49  Zona urbana       SE      0                   ALCANAR            Montsia
# 50  Zona urbana       SE      0                 BARCELONA         Barcelones
# 51    Carretera   GI-634    1,1                    VERGES       Baix Emporda
# 52  Zona urbana       SE      0                      GAVA     Baix Llobregat
# 53    Carretera  BV-2415    0,8                  OLERDOLA        Alt Penedes
# 54  Zona urbana       SE      0                 BARCELONA         Barcelones
# 55    Carretera     C-31  165,9                    SITGES             Garraf
# 56  Zona urbana       SE      0                  FIGUERES        Alt Emporda
# 57    Carretera     C-66   21,2                     FLACA            Girones
# 58  Zona urbana       SE      0               PALAFRUGELL       Baix Emporda
# 59    Carretera     C-59   14,1         CALDES DE MONTBUI    Valles Oriental
#
#        nomdem f_morts f_ferits_greus f_ferits_lleus  f_unitats_implicades  \
# 0   Barcelona      Si             No             Si                     2
# 1      Lleida      Si             No             No                     1
# 2      Girona      No             Si             No                     4
# 3   Barcelona      Si             No             No                     2
# 4   Barcelona      Si             No             Si                     1
# 5   Tarragona      Si             No             No                     2
# 6   Barcelona      Si             No             Si                     2
# 7   Barcelona      No             Si             No                     2
# 8   Barcelona      Si             No             No                     2
# 9   Barcelona      Si             No             Si                     2
# 10     Girona      Si             No             No                     3
# 11  Barcelona      Si             No             Si                     2
# 12     Girona      Si             No             Si                     2
# 13  Barcelona      Si             No             Si                     2
# 14  Tarragona      Si             No             Si                     2
# 15     Girona      Si             No             No                     3
# 16     Lleida      Si             No             Si                     2
# 17  Barcelona      Si             No             No                     3
# 18  Barcelona      No             Si             Si                     2
# 19     Lleida      Si             No             No                     3
# 20     Girona      Si             No             No                     2
# 21     Lleida      Si             No             Si                     1
# 22  Barcelona      Si             No             No                     2
# 23  Barcelona      Si             No             Si                     1
# 24  Barcelona      No             Si             Si                     2
# 25  Barcelona      Si             No             Si                     1
# 26  Barcelona      Si             No             Si                     2
# 27     Lleida      No             Si             Si                     2
# 28  Barcelona      Si             No             Si                     2
# 29  Barcelona      Si             No             No                     2
# 30  Tarragona      Si             No             Si                     1
# 31  Tarragona      Si             No             Si                     3
# 32  Barcelona      Si             No             Si                     2
# 33  Barcelona      Si             No             Si                     2
# 34  Barcelona      Si             No             No                     2
# 35  Barcelona      Si             No             No                     6
# 36  Barcelona      No             No             No                     4
# 37  Barcelona      Si             No             Si                     2
# 38     Girona      Si             No             Si                     3
# 39  Barcelona      Si             No             Si                     1
# 40  Barcelona      Si             No             Si                     2
# 41  Barcelona      Si             No             Si                     2
# 42  Tarragona      Si             No             No                     2
# 43  Barcelona      Si             No             Si                     2
# 44  Barcelona      No             Si             No                     2
# 45     Girona      No             Si             Si                     1
# 46     Girona      Si             No             Si                     2
# 47  Tarragona      Si             No             Si                     1
# 48  Barcelona      Si             No             Si                     2
# 49  Tarragona      No             Si             Si                     2
# 50  Barcelona      Si             No             Si                     2
# 51     Girona      Si             No             No                     2
# 52  Barcelona      Si             No             Si                     1
# 53  Barcelona      No             Si             No                     2
# 54  Barcelona      Si             No             Si                     2
# 55  Barcelona      Si             No             Si                     1
# 56     Girona      Si             No             Si                     2
# 57     Girona      Si             No             Si                     4
# 58     Girona      Si             No             Si                     2
# 59  Barcelona      Si             No             Si                     2
#
#    f_vianants_implicades  f_bicicletes_implicades f_ciclomotors_implicades  \
# 0                     Si                        0                       Si
# 1                     Si                        0                       Si
# 2                     Si                        0                       Si
# 3                     Si                        0                       Si
# 4                     Si                        0                       Si
# 5                     Si                        0                       No
# 6                     Si                        0                       Si
# 7                     No                        0                       Si
# 8                     Si                        0                       Si
# 9                     Si                        0                       Si
# 10                    No                        0                       Si
# 11                    Si                        0                       No
# 12                    Si                        0                       Si
# 13                    Si                        0                       Si
# 14                    No                        0                       Si
# 15                    No                        0                       Si
# 16                    No                        0                       Si
# 17                    Si                        0                       Si
# 18                    No                        0                       Si
# 19                    Si                        0                       Si
# 20                    Si                        0                       Si
# 21                    Si                        0                       Si
# 22                    Si                        0                       Si
# 23                    Si                        0                       Si
# 24                    Si                        0                       Si
# 25                    Si                        0                       Si
# 26                    No                        0                       Si
# 27                    No                        0                       Si
# 28                    No                        0                       Si
# 29                    No                        0                       No
# 30                    Si                        0                       Si
# 31                    Si                        0                       No
# 32                    No                        0                       Si
# 33                    Si                        0                       No
# 34                    Si                        0                       Si
# 35                    Si                        0                       No
# 36                    Si                        0                       Si
# 37                    No                        0                       Si
# 38                    Si                        0                       Si
# 39                    Si                        0                       Si
# 40                    Si                        0                       Si
# 41                    Si                        0                       Si
# 42                    Si                        0                       Si
# 43                    Si                        0                       Si
# 44                    Si                        0                       Si
# 45                    Si                        0                       Si
# 46                    No                        0                       Si
# 47                    Si                        0                       Si
# 48                    No                        0                       Si
# 49                    No                        0                       Si
# 50                    Si                        0                       Si
# 51                    Si                        0                       Si
# 52                    Si                        1                       Si
# 53                    Si                        1                       Si
# 54                    No                        0                       Si
# 55                    Si                        0                       Si
# 56                    Si                        0                       Si
# 57                    Si                        0                       Si
# 58                    No                        0                       Si
# 59                    Si                        1                       Si
#
#    f_motocicletes_implicades f_veh_lleugers_implicades  \
# 0                         Si                        No
# 1                         Si                        No
# 2                         Si                        No
# 3                         Si                        No
# 4                         No                        Si
# 5                         Si                        No
# 6                         No                        No
# 7                         No                        Si
# 8                         Si                        No
# 9                         No                        No
# 10                        Si                        No
# 11                        Si                        No
# 12                        No                        No
# 13                        No                        No
# 14                        No                        Si
# 15                        No                        No
# 16                        Si                        No
# 17                        Si                        No
# 18                        Si                        No
# 19                        Si                        No
# 20                        Si                        No
# 21                        Si                        No
# 22                        Si                        No
# 23                        Si                        No
# 24                        No                        No
# 25                        Si                        No
# 26                        Si                        Si
# 27                        Si                        No
# 28                        Si                        No
# 29                        Si                        Si
# 30                        Si                        Si
# 31                        Si                        No
# 32                        Si                        No
# 33                        No                        Si
# 34                        Si                        No
# 35                        No                        Si
# 36                        Si                        No
# 37                        Si                        Si
# 38                        No                        No
# 39                        No                        Si
# 40                        No                        No
# 41                        No                        No
# 42                        Si                        No
# 43                        No                        Si
# 44                        No                        No
# 45                        No                        Si
# 46                        Si                        No
# 47                        No                        Si
# 48                        Si                        No
# 49                        Si                        Si
# 50                        No                        No
# 51                        Si                        Si
# 52                        Si                        Si
# 53                        No                        Si
# 54                        Si                        No
# 55                        No                        Si
# 56                        No                        No
# 57                        Si                        No
# 58                        No                        Si
# 59                        Si                        Si
#
#    f_veh_pesants_implicades f_altres_unit_implicades c_velocitat_via  \
# 0                        Si                       No          60-100
# 1                        Si                       Si           20-60
# 2                        No                       Si          60-100
# 3                        Si                       Si          60-100
# 4                        Si                       Si          60-100
# 5                        Si                       Si           20-60
# 6                        Si                       Si          60-100
# 7                        Si                       Si          60-100
# 8                        Si                       Si          60-100
# 9                        Si                       Si          60-100
# 10                       Si                       Si          60-100
# 11                       Si                       Si           20-60
# 12                       Si                       Si          60-100
# 13                       Si                       Si          60-100
# 14                       Si                       Si          60-100
# 15                       Si                       Si           20-60
# 16                       Si                       Si          60-100
# 17                       Si                       Si          60-100
# 18                       Si                       Si          60-100
# 19                       Si                       Si          60-100
# 20                       Si                       Si          60-100
# 21                       Si                       Si          60-100
# 22                       No                       Si           20-60
# 23                       Si                       Si          60-100
# 24                       Si                       Si           20-60
# 25                       Si                       Si          60-100
# 26                       No                       Si          60-100
# 27                       Si                       Si          60-100
# 28                       Si                       Si          60-100
# 29                       Si                       Si          60-100
# 30                       No                       Si          60-100
# 31                       Si                       Si           20-60
# 32                       Si                       Si          60-100
# 33                       Si                       Si           20-60
# 34                       No                       Si          60-100
# 35                       No                       Si          60-100
# 36                       Si                       Si          60-100
# 37                       No                       Si          60-100
# 38                       Si                       Si          60-100
# 39                       Si                       Si          60-100
# 40                       Si                       Si          60-100
# 41                       Si                       Si           20-60
# 42                       No                       Si          60-100
# 43                       No                       Si          60-100
# 44                       Si                       Si          60-100
# 45                       Si                       Si          60-100
# 46                       Si                       Si          60-100
# 47                       Si                       Si          60-100
# 48                       Si                       Si          60-100
# 49                       No                       Si          60-100
# 50                       Si                       Si          60-100
# 51                       No                       Si          60-100
# 52                       Si                       Si          60-100
# 53                       Si                       Si           20-60
# 54                       Si                       Si          60-100
# 55                       Si                       Si           20-60
# 56                       Si                       Si          60-100
# 57                       Si                       Si          60-100
# 58                       Si                       Si          60-100
# 59                       No                       Si          60-100
#
#    d_acc_amb_fuga d_boira    d_caract_entorn d_carril_especial  \
# 0              No      No            Desmunt                No
# 1              No      No           A nivell                No
# 2              No      No           A nivell                No
# 3              No      No  Sense Especificar                No
# 4              No      No  Sense Especificar                No
# 5              No      No               Mixt                No
# 6              No      No  Sense Especificar                No
# 7              No      No  Sense Especificar                No
# 8              No      No            Desmunt                No
# 9              No      No           A nivell                No
# 10             No      No           A nivell                No
# 11             No      No           A nivell                No
# 12             No      No               Mixt                No
# 13             No      No  Sense Especificar                No
# 14             No      No  Sense Especificar                No
# 15             No      No           A nivell                No
# 16             No      No  Sense Especificar                No
# 17             No      No           Terraplé                No
# 18             No      No  Sense Especificar                No
# 19             No      No               Mixt                No
# 20             No      No           Terraplé                No
# 21             No      No           A nivell                No
# 22             No      No           A nivell                No
# 23             No      No           A nivell                No
# 24             No      No           A nivell                No
# 25             No      No           A nivell                No
# 26             No      No  Sense Especificar                No
# 27             No      No           A nivell                No
# 28             No      No  Sense Especificar                No
# 29             No      No           A nivell                No
# 30             No      No  Sense Especificar                No
# 31             No      No           A nivell                No
# 32             No      No  Sense Especificar                No
# 33             No      No  Sense Especificar                Si
# 34             No      No               Mixt                No
# 35             No      No  Sense Especificar                No
# 36             No      No           A nivell                No
# 37             No      No  Sense Especificar                No
# 38             No      No           A nivell                Si
# 39             No      No               Mixt                No
# 40             No      No           A nivell                No
# 41             No      No  Sense Especificar                No
# 42             No      No               Mixt                Si
# 43             No      No  Sense Especificar                No
# 44             No      No            Desmunt                No
# 45             No      No               Mixt                No
# 46             No      No           A nivell                No
# 47             No      No           A nivell                No
# 48             No      No           A nivell                No
# 49             No      No           A nivell                No
# 50             No      No  Sense Especificar                No
# 51             No      No            Desmunt                No
# 52             No      No               Mixt                No
# 53             No      No            Desmunt                No
# 54             No      No  Sense Especificar                No
# 55             No      No           Terraplé                No
# 56             No      No           A nivell                No
# 57             No      No               Mixt                No
# 58             No      No  Sense Especificar                No
# 59             No      No           A nivell                No
#
#    d_circulacio_mesures_esp d_climatologia d_func_esp_via       d_gravetat  \
# 0                        No      Bon temps     Via normal    Accident greu
# 1                        No      Bon temps     Via normal    Accident greu
# 2                        No      Bon temps   Via especial  Accident mortal
# 3                        No      Bon temps     Via normal    Accident greu
# 4                        No      Bon temps     Via normal    Accident greu
# 5                        No      Bon temps     Via normal    Accident greu
# 6                        No      Bon temps     Via normal    Accident greu
# 7                        No      Bon temps     Via normal  Accident mortal
# 8                        No      Bon temps     Via normal    Accident greu
# 9                        No      Bon temps     Via normal    Accident greu
# 10                       No      Bon temps   Via especial    Accident greu
# 11                       No      Bon temps     Via normal    Accident greu
# 12                       No      Bon temps   Via especial    Accident greu
# 13                       No      Bon temps     Via normal    Accident greu
# 14                       No      Bon temps     Via normal    Accident greu
# 15                       No      Bon temps     Via normal    Accident greu
# 16                       No      Bon temps     Via normal    Accident greu
# 17                       No      Bon temps     Via normal    Accident greu
# 18                       No      Bon temps     Via normal  Accident mortal
# 19                       No      Bon temps     Via normal    Accident greu
# 20                       No      Bon temps     Via normal    Accident greu
# 21                       No      Bon temps     Via normal    Accident greu
# 22                       No      Bon temps   Via especial    Accident greu
# 23                       No      Mal temps     Via normal    Accident greu
# 24                       No      Bon temps     Via normal  Accident mortal
# 25                       No      Bon temps     Via normal    Accident greu
# 26                       No      Bon temps     Via normal    Accident greu
# 27                       No      Bon temps   Via especial  Accident mortal
# 28                       No      Bon temps     Via normal    Accident greu
# 29                       No      Bon temps     Via normal    Accident greu
# 30                       No      Bon temps     Via normal    Accident greu
# 31                       No      Bon temps   Via especial    Accident greu
# 32                       No      Bon temps     Via normal    Accident greu
# 33                       Si      Bon temps     Via normal    Accident greu
# 34                       No      Bon temps     Via normal    Accident greu
# 35                       No      Bon temps     Via normal    Accident greu
# 36                       No      Mal temps     Via normal  Accident mortal
# 37                       No      Bon temps     Via normal    Accident greu
# 38                       No      Bon temps     Via normal    Accident greu
# 39                       No      Bon temps     Via normal    Accident greu
# 40                       No      Bon temps     Via normal    Accident greu
# 41                       No      Bon temps     Via normal    Accident greu
# 42                       No      Bon temps   Via especial    Accident greu
# 43                       No      Bon temps     Via normal    Accident greu
# 44                       No      Bon temps     Via normal  Accident mortal
# 45                       No      Bon temps     Via normal  Accident mortal
# 46                       No      Bon temps     Via normal    Accident greu
# 47                       No      Bon temps     Via normal    Accident greu
# 48                       No      Bon temps     Via normal    Accident greu
# 49                       No      Bon temps     Via normal  Accident mortal
# 50                       No      Bon temps     Via normal    Accident greu
# 51                       No      Bon temps     Via normal    Accident greu
# 52                       No      Bon temps     Via normal    Accident greu
# 53                       No      Bon temps     Via normal  Accident mortal
# 54                       No      Bon temps     Via normal    Accident greu
# 55                       No      Bon temps     Via normal    Accident greu
# 56                       No      Bon temps     Via normal    Accident greu
# 57                       No      Bon temps     Via normal    Accident greu
# 58                       No      Bon temps     Via normal    Accident greu
# 59                       No      Bon temps     Via normal    Accident greu
#
#    d_influit_boira d_influit_caract_entorn d_influit_circulacio  \
# 0               No                      No                   No
# 1               No                      No                   No
# 2               No                      No                   No
# 3               No                      No                   No
# 4               No                      No                   No
# 5               No                      No                   No
# 6               No                      No                   No
# 7               No                      No                   No
# 8               No                      No                   No
# 9               No                      No                   No
# 10              No                      No                   No
# 11              No                      No                   No
# 12              No                      No                   No
# 13              No                      No                   No
# 14              No                      No                   No
# 15              No                      No                   No
# 16              No                      No                   No
# 17              No                      No                   No
# 18              No                      No                   No
# 19              No                      No                   No
# 20              No                      No                   No
# 21              No                      No                   No
# 22              No                      No                   No
# 23              No                      No                   No
# 24              No                      No                   No
# 25              No                      No                   No
# 26              No                      No                   No
# 27              No                      No                   No
# 28              No                      No                   No
# 29              No                      No                   No
# 30              No                      No                   No
# 31              No                      Si                   No
# 32              No                      No                   No
# 33              No                      No                   No
# 34              No                      No                   No
# 35              No                      No                   No
# 36              No                      No                   No
# 37              No                      No                   No
# 38              No                      No                   No
# 39              No                      No                   No
# 40              No                      No                   No
# 41              No                      No                   No
# 42              No                      No                   No
# 43              No                      No                   No
# 44              No                      No                   No
# 45              No                      No                   No
# 46              No                      No                   No
# 47              No                      No                   No
# 48              No                      No                   No
# 49              No                      No                   No
# 50              No                      No                   Si
# 51              No                      No                   No
# 52              No                      Si                   No
# 53              No                      No                   No
# 54              No                      No                   No
# 55              No                      No                   No
# 56              No                      No                   No
# 57              No                      No                   No
# 58              No                      No                   No
# 59              No                      No                   No
#
#    d_influit_estat_clima d_influit_inten_vent d_influit_lluminositat  \
# 0                     No                   No                     No
# 1                     No                   No                     No
# 2                     No                   No                     No
# 3                     No                   No                     No
# 4                     No                   No                     No
# 5                     No                   No                     No
# 6                     No                   No                     No
# 7                     No                   No                     No
# 8                     No                   No                     No
# 9                     No                   No                     No
# 10                    No                   No                     Si
# 11                    No                   No                     No
# 12                    No                   No                     No
# 13                    No                   No                     No
# 14                    No                   No                     No
# 15                    No                   No                     No
# 16                    No                   No                     No
# 17                    No                   No                     No
# 18                    No                   No                     No
# 19                    No                   No                     No
# 20                    No                   No                     No
# 21                    No                   No                     No
# 22                    No                   No                     No
# 23                    Si                   No                     No
# 24                    No                   No                     No
# 25                    No                   No                     No
# 26                    No                   No                     No
# 27                    No                   No                     Si
# 28                    No                   No                     No
# 29                    No                   No                     No
# 30                    No                   No                     No
# 31                    No                   No                     No
# 32                    No                   No                     No
# 33                    No                   No                     No
# 34                    No                   No                     No
# 35                    No                   No                     No
# 36                    No                   No                     No
# 37                    No                   No                     No
# 38                    No                   No                     No
# 39                    No                   No                     Si
# 40                    No                   No                     No
# 41                    No                   No                     No
# 42                    No                   No                     No
# 43                    No                   No                     No
# 44                    No                   No                     No
# 45                    No                   No                     Si
# 46                    No                   No                     No
# 47                    No                   No                     No
# 48                    No                   No                     No
# 49                    No                   No                     No
# 50                    No                   No                     No
# 51                    No                   No                     No
# 52                    No                   No                     No
# 53                    No                   No                     No
# 54                    No                   No                     No
# 55                    No                   No                     No
# 56                    No                   No                     No
# 57                    No                   No                     No
# 58                    No                   No                     No
# 59                    No                   No                     No
#
#    d_influit_mesu_esp d_influit_obj_calcada d_influit_solcs_rases  \
# 0                  No                    No                    No
# 1                  No                    No                    No
# 2                  No                    No                    No
# 3                  No                    No                    No
# 4                  No                    No                    No
# 5                  No                    No                    No
# 6                  No                    No                    No
# 7                  No                    No                    No
# 8                  No                    No                    No
# 9                  No                    No                    No
# 10                 No                    No                    No
# 11                 No                    No                    No
# 12                 No                    No                    No
# 13                 No                    No                    No
# 14                 No                    No                    No
# 15                 No                    No                    No
# 16                 No                    No                    No
# 17                 No                    No                    No
# 18                 No                    No                    No
# 19                 No                    No                    No
# 20                 No                    No                    No
# 21                 No                    No                    No
# 22                 No                    No                    No
# 23                 No                    No                    No
# 24                 No                    No                    No
# 25                 No                    No                    No
# 26                 No                    No                    No
# 27                 No                    No                    No
# 28                 No                    No                    No
# 29                 No                    No                    No
# 30                 No                    No                    No
# 31                 No                    No                    No
# 32                 No                    No                    No
# 33                 Si                    No                    No
# 34                 No                    No                    No
# 35                 No                    Si                    No
# 36                 No                    No                    No
# 37                 No                    No                    No
# 38                 No                    No                    No
# 39                 No                    No                    No
# 40                 No                    No                    No
# 41                 No                    No                    No
# 42                 No                    No                    No
# 43                 No                    No                    No
# 44                 No                    No                    No
# 45                 No                    No                    No
# 46                 No                    No                    No
# 47                 No                    No                    No
# 48                 No                    No                    No
# 49                 No                    No                    No
# 50                 No                    No                    No
# 51                 No                    No                    No
# 52                 No                    Si                    Si
# 53                 No                    No                    No
# 54                 No                    No                    No
# 55                 No                    No                    No
# 56                 No                    No                    No
# 57                 No                    No                    No
# 58                 No                    No                    No
# 59                 No                    No                    No
#
#    d_influit_visibilitat                          d_inter_seccio  \
# 0                     No  Arribant o eixint intersecció fins 50m
# 1                     No                      Dintre intersecció
# 2                     No                               En secció
# 3                     No                      Dintre intersecció
# 4                     No                      Dintre intersecció
# 5                     No                      Dintre intersecció
# 6                     No                               En secció
# 7                     No                               En secció
# 8                     No                               En secció
# 9                     No                               En secció
# 10                    No                               En secció
# 11                    No                               En secció
# 12                    No                               En secció
# 13                    No                               En secció
# 14                    No                               En secció
# 15                    No                               En secció
# 16                    No                               En secció
# 17                    No  Arribant o eixint intersecció fins 50m
# 18                    No                               En secció
# 19                    No                      Dintre intersecció
# 20                    No                               En secció
# 21                    No                               En secció
# 22                    No                      Dintre intersecció
# 23                    No                               En secció
# 24                    No  Arribant o eixint intersecció fins 50m
# 25                    No                      Dintre intersecció
# 26                    No                               En secció
# 27                    No                               En secció
# 28                    No                               En secció
# 29                    No                               En secció
# 30                    Si                               En secció
# 31                    No                               En secció
# 32                    No                               En secció
# 33                    No                               En secció
# 34                    No                               En secció
# 35                    No                               En secció
# 36                    No                               En secció
# 37                    No                               En secció
# 38                    No                      Dintre intersecció
# 39                    No                               En secció
# 40                    No                               En secció
# 41                    No                      Dintre intersecció
# 42                    No                      Dintre intersecció
# 43                    No                               En secció
# 44                    No                               En secció
# 45                    No  Arribant o eixint intersecció fins 50m
# 46                    No                      Dintre intersecció
# 47                    No                               En secció
# 48                    No                               En secció
# 49                    No                      Dintre intersecció
# 50                    No                               En secció
# 51                    No                               En secció
# 52                    No                               En secció
# 53                    No  Arribant o eixint intersecció fins 50m
# 54                    No                      Dintre intersecció
# 55                    No                               En secció
# 56                    Si                      Dintre intersecció
# 57                    No                               En secció
# 58                    No                               En secció
# 59                    No                      Dintre intersecció
#
#    d_limit_velocitat                             d_lluminositat  \
# ...
# 35                       Recta  Zona urbana  Mullat o altres condicions
# 36                       Recta    Carretera  Mullat o altres condicions
# 37                       Recta  Zona urbana                   Sec i net
# 38  Encreuament o altres tipus  Zona urbana                   Sec i net
# 39                       Recta    Carretera                   Sec i net
# 40                       Recta  Zona urbana                   Sec i net
# 41  Encreuament o altres tipus  Zona urbana                   Sec i net
# 42  Encreuament o altres tipus    Carretera                   Sec i net
# 43                       Recta  Zona urbana                   Sec i net
# 44                       Recta    Carretera                   Sec i net
# 45  Encreuament o altres tipus    Carretera                   Sec i net
# 46  Encreuament o altres tipus  Zona urbana  Mullat o altres condicions
# 47                       Recta    Carretera                   Sec i net
# 48                       Recta  Zona urbana                   Sec i net
# 49  Encreuament o altres tipus  Zona urbana                   Sec i net
# 50                       Recta  Zona urbana                   Sec i net
# 51                       Recta    Carretera                   Sec i net
# 52                       Recta  Zona urbana  Mullat o altres condicions
# 53  Encreuament o altres tipus    Carretera                   Sec i net
# 54  Encreuament o altres tipus  Zona urbana                   Sec i net
# 55                       Recta    Carretera                   Sec i net
# 56  Encreuament o altres tipus  Zona urbana                   Sec i net
# 57                       Recta    Carretera                   Sec i net
# 58                       Recta  Zona urbana                   Sec i net
# 59  Encreuament o altres tipus    Carretera                   Sec i net
#
#                                         d_tipus_via  d_titularitat_via  \
# 0   Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 1                            Carretera convencional            Estatal
# 2                            Carretera convencional            Estatal
# 3   Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 4   Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 5                                            Altres          Municipal
# 6   Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 7   Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 8                            Carretera convencional            Estatal
# 9                                            Altres          Municipal
# 10                           Carretera convencional         Autonòmica
# 11  Via urbana( inclou carrer i carrer residencial)          Municipal
# 12                           Carretera convencional            Estatal
# 13  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 14  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 15  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 16  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 17                           Carretera convencional         Provincial
# 18  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 19                           Carretera convencional         Autonòmica
# 20                           Carretera convencional         Autonòmica
# 21                           Carretera convencional         Provincial
# 22  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 23                           Carretera convencional         Autonòmica
# 24  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 25  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 26                                           Altres  Sense Especificar
# 27  Via urbana( inclou carrer i carrer residencial)         Autonòmica
# 28  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 29  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 30  Via urbana( inclou carrer i carrer residencial)          Municipal
# 31                           Carretera convencional         Provincial
# 32  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 33                           Carretera convencional         Provincial
# 34                           Carretera convencional         Autonòmica
# 35  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 36                           Carretera convencional         Autonòmica
# 37  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 38  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 39                           Carretera convencional         Provincial
# 40  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 41  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 42                           Carretera convencional         Autonòmica
# 43  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 44                           Carretera convencional            Estatal
# 45                                           Altres             Altres
# 46  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 47                           Carretera convencional         Provincial
# 48  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 49  Via urbana( inclou carrer i carrer residencial)          Municipal
# 50  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 51                           Carretera convencional         Provincial
# 52  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 53                           Carretera convencional         Provincial
# 54  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 55                           Carretera convencional         Autonòmica
# 56  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 57                           Carretera convencional  Sense Especificar
# 58  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 59                           Carretera convencional         Autonòmica
#
#    d_tracat_altimetric d_vent    grupdialab    hor gruphor  \
# 0    Sense especificar     No       Feiners  23,33     Nit
# 1                  Pla     No  CapDeSetmana      1     Nit
# 2      Rampa o pendent     No       Feiners  15,27   Tarda
# 3    Sense especificar     No  CapDeSetmana   22,3     Nit
# 4    Sense especificar     No  CapDeSetmana  17,45   Tarda
# 5      Rampa o pendent     No       Feiners  14,57   Tarda
# 6    Sense especificar     No       Feiners  20,54   Tarda
# 7    Sense especificar     No  CapDeSetmana  10,55    Matí
# 8                  Pla     No  CapDeSetmana    5,3     Nit
# 9                  Pla     No       Feiners   14,3   Tarda
# 10                 Pla     No       Feiners   18,3   Tarda
# 11                 Pla     No       Feiners   13,5    Matí
# 12                 Pla     No  CapDeSetmana  16,05   Tarda
# 13   Sense especificar     No       Feiners    9,1    Matí
# 14   Sense especificar     No       Feiners     13    Matí
# 15   Sense especificar     No  CapDeSetmana  13,02    Matí
# 16   Sense especificar     No       Feiners   9,15    Matí
# 17     Rampa o pendent     No       Feiners      8    Matí
# 18   Sense especificar     No  CapDeSetmana   16,4   Tarda
# 19     Rampa o pendent     No  CapDeSetmana  11,04    Matí
# 20     Rampa o pendent     No       Feiners  15,15   Tarda
# 21                 Pla     No       Feiners     13    Matí
# 22   Sense especificar     No       Feiners   11,2    Matí
# 23     Rampa o pendent     No       Feiners   14,5   Tarda
# 24   Sense especificar     No       Feiners   5,51     Nit
# 25   Sense especificar     No  CapDeSetmana   7,47    Matí
# 26   Sense especificar     No       Feiners  11,39    Matí
# 27                 Pla     No       Feiners  20,25   Tarda
# 28   Sense especificar     No  CapDeSetmana   15,3   Tarda
# 29   Sense especificar     No  CapDeSetmana   22,3     Nit
# 30                 Pla     No  CapDeSetmana  17,45   Tarda
# 31                 Pla     No       Feiners  20,41   Tarda
# 32   Sense especificar     No       Feiners   12,2    Matí
# 33   Sense especificar     No       Feiners    9,5    Matí
# 34     Rampa o pendent     No  CapDeSetmana  19,46   Tarda
# 35   Sense especificar     No       Feiners    6,5    Matí
# 36                 Pla     No  CapDeSetmana  18,58   Tarda
# 37   Sense especificar     No       Feiners  13,48    Matí
# 38   Sense especificar     No  CapDeSetmana   18,2   Tarda
# 39                 Pla     No       Feiners    7,1    Matí
# 40   Sense especificar     No       Feiners  17,55   Tarda
# 41   Sense especificar     No  CapDeSetmana  15,15   Tarda
# 42     Rampa o pendent     No  CapDeSetmana  10,45    Matí
# 43   Sense especificar     No  CapDeSetmana  15,35   Tarda
# 44                 Pla     No       Feiners  11,42    Matí
# 45     Rampa o pendent     No  CapDeSetmana      4     Nit
# 46   Sense especificar     No       Feiners  10,55    Matí
# 47                 Pla     No  CapDeSetmana  13,55    Matí
# 48   Sense especificar     No  CapDeSetmana  19,38   Tarda
# 49                 Pla     No       Feiners    1,2     Nit
# 50   Sense especificar     No  CapDeSetmana   18,1   Tarda
# 51                 Pla     No       Feiners   7,27    Matí
# 52   Sense especificar     No       Feiners  13,15    Matí
# 53     Rampa o pendent     No  CapDeSetmana  10,05    Matí
# 54   Sense especificar     No       Feiners  19,15   Tarda
# 55                 Pla     No  CapDeSetmana   8,04    Matí
# 56   Sense especificar     No       Feiners      9    Matí
# 57                 Pla     No  CapDeSetmana  13,53    Matí
# 58   Sense especificar     No  CapDeSetmana  10,58    Matí
# 59                 Pla     No       Feiners   16,5   Tarda
#
#                                                tipacc  year  month  weekday  \
# 0                      Col.lisió de vehicles en marxa  2010      1        0
# 1             Sortida de la calcada sense especificar  2010     10        6
# 2                      Col.lisió de vehicles en marxa  2010      5        0
# 3                      Col.lisió de vehicles en marxa  2010      8        5
# 4                                Bolcada a la calcada  2010      7        0
# 5                      Col.lisió de vehicles en marxa  2010      8        0
# 6                      Col.lisió de vehicles en marxa  2010      1        2
# 7                                       Atropellament  2010     10        5
# 8                      Col.lisió de vehicles en marxa  2010      6        5
# 9                      Col.lisió de vehicles en marxa  2010     12        3
# 10                                      Atropellament  2010      6        2
# 11                     Col.lisió de vehicles en marxa  2010     12        4
# 12                     Col.lisió de vehicles en marxa  2010      5        6
# 13                               Bolcada a la calcada  2010     12        4
# 14                                      Atropellament  2010     10        4
# 15                                      Atropellament  2010      6        6
# 16                                      Atropellament  2010      9        2
# 17                     Col.lisió de vehicles en marxa  2010      7        2
# 18                                      Atropellament  2010      2        6
# 19                     Col.lisió de vehicles en marxa  2010      3        5
# 20                     Col.lisió de vehicles en marxa  2010      8        1
# 21  Col.lisió d'un vehicle contra un obstacle de l...  2010     12        4
# 22                     Col.lisió de vehicles en marxa  2010     10        1
# 23            Sortida de la calcada sense especificar  2010      5        4
# 24                     Col.lisió de vehicles en marxa  2010      8        0
# 25  Col.lisió d'un vehicle contra un obstacle de l...  2010     10        6
# 26                                      Atropellament  2010      8        2
# 27                                      Atropellament  2010      6        2
# 28                                      Atropellament  2010      1        6
# 29                                      Atropellament  2010      3        3
# 30                               Bolcada a la calcada  2010     12        3
# 31                     Col.lisió de vehicles en marxa  2010      9        1
# 32                                      Atropellament  2010      2        3
# 33                     Col.lisió de vehicles en marxa  2010      7        1
# 34                     Col.lisió de vehicles en marxa  2010      2        6
# 35                               Bolcada a la calcada  2010     11        2
# 36                     Col.lisió de vehicles en marxa  2010      3        0
# 37                                      Atropellament  2010      4        2
# 38                     Col.lisió de vehicles en marxa  2010     10        6
# 39            Sortida de la calcada sense especificar  2010      4        3
# 40  Col.lisió d'un vehicle contra un obstacle de l...  2010      7        2
# 41                     Col.lisió de vehicles en marxa  2010      9        4
# 42                     Col.lisió de vehicles en marxa  2010     10        5
# 43                     Col.lisió de vehicles en marxa  2010     10        1
# 44                     Col.lisió de vehicles en marxa  2010      7        1
# 45  Col.lisió d'un vehicle contra un obstacle de l...  2010     10        3
# 46                                      Atropellament  2010      8        4
# 47            Sortida de la calcada sense especificar  2010      4        6
# 48                                      Atropellament  2010     12        5
# 49                                      Atropellament  2010      5        1
# 50                     Col.lisió de vehicles en marxa  2010      3        4
# 51                     Col.lisió de vehicles en marxa  2010      1        3
# 52                               Bolcada a la calcada  2010      1        4
# 53                     Col.lisió de vehicles en marxa  2010      1        6
# 54                                      Atropellament  2010      8        2
# 55  Col.lisió d'un vehicle contra un obstacle de l...  2010      5        5
# 56                     Col.lisió de vehicles en marxa  2010      8        4
# 57                     Col.lisió de vehicles en marxa  2010      8        3
# 58                                      Atropellament  2010      5        3
# 59                     Col.lisió de vehicles en marxa  2010      7        1
#
#      day_name
# 0      Monday
# 1      Sunday
# 2      Monday
# 3    Saturday
# 4      Monday
# 5      Monday
# 6   Wednesday
# 7    Saturday
# 8    Saturday
# 9    Thursday
# 10  Wednesday
# 11     Friday
# 12     Sunday
# 13     Friday
# 14     Friday
# 15     Sunday
# 16  Wednesday
# 17  Wednesday
# 18     Sunday
# 19   Saturday
# 20    Tuesday
# 21     Friday
# 22    Tuesday
# 23     Friday
# 24     Monday
# 25     Sunday
# 26  Wednesday
# 27  Wednesday
# 28     Sunday
# 29   Thursday
# 30   Thursday
# 31    Tuesday
# 32   Thursday
# 33    Tuesday
# 34     Sunday
# 35  Wednesday
# 36     Monday
# 37  Wednesday
# 38     Sunday
# 39   Thursday
# 40  Wednesday
# 41     Friday
# 42   Saturday
# 43    Tuesday
# 44    Tuesday
# 45   Thursday
# 46     Friday
# 47     Sunday
# 48   Saturday
# 49    Tuesday
# 50     Friday
# 51   Thursday
# 52     Friday
# 53     Sunday
# 54  Wednesday
# 55   Saturday
# 56     Friday
# 57   Thursday
# 58   Thursday
# 59    Tuesday

# %% [markdown]
# # Checking and changing some types.

# %%
Accidents_cleaned.dtypes
# Out:
# zona                         object
# via                          object
# pk                           object
# nommun                       object
# nomcom                       object
# nomdem                       object
# f_morts                      object
# f_ferits_greus               object
# f_ferits_lleus               object
# f_unitats_implicades          int64
# f_vianants_implicades        object
# f_bicicletes_implicades       int64
# f_ciclomotors_implicades     object
# f_motocicletes_implicades    object
# f_veh_lleugers_implicades    object
# f_veh_pesants_implicades     object
# f_altres_unit_implicades     object
# c_velocitat_via              object
# d_acc_amb_fuga               object
# d_boira                      object
# d_caract_entorn              object
# d_carril_especial            object
# d_circulacio_mesures_esp     object
# d_climatologia               object
# d_func_esp_via               object
# d_gravetat                   object
# d_influit_boira              object
# d_influit_caract_entorn      object
# d_influit_circulacio         object
# d_influit_estat_clima        object
# d_influit_inten_vent         object
# d_influit_lluminositat       object
# d_influit_mesu_esp           object
# d_influit_obj_calcada        object
# d_influit_solcs_rases        object
# d_influit_visibilitat        object
# d_inter_seccio               object
# d_limit_velocitat            object
# d_lluminositat               object
# d_regulacio_prioritat        object
# d_sentits_via                object
# d_subtipus_accident          object
# d_subtipus_tram              object
# d_subzona                    object
# d_superficie                 object
# d_tipus_via                  object
# d_titularitat_via            object
# d_tracat_altimetric          object
# d_vent                       object
# grupdialab                   object
# hor                          object
# gruphor                      object
# tipacc                       object
# year                          int64
# month                         int64
# weekday                       int64
# day_name                     object
# dtype: object

# %%
Accidents_cleaned["pk"] = [float(str(i).replace(",", "")) for i in Accidents_cleaned["pk"]]
Accidents_cleaned["hor"] = [float(str(i).replace(",", "")) for i in Accidents_cleaned["hor"]]

# %%
Accidents_cleaned.select_dtypes(np.number)
# Out:
#            pk  f_unitats_implicades  f_bicicletes_implicades     hor  year  \
# 0         0.0                     2                        0  2333.0  2010
# 1       999.0                     1                        0     1.0  2010
# 2      7087.0                     4                        0  1527.0  2010
# 3         0.0                     2                        0   223.0  2010
# 4         0.0                     1                        0  1745.0  2010
# ...       ...                   ...                      ...     ...   ...
# 21156    28.0                     2                        0  1128.0  2021
# 21157     0.0                     2                        0  1455.0  2021
# 21158    85.0                     2                        0   949.0  2021
# 21159     0.0                     2                        0  1244.0  2021
# 21160     0.0                     2                        0   113.0  2021
#
#        month  weekday
# 0          1        0
# 1         10        6
# 2          5        0
# 3          8        5
# 4          7        0
# ...      ...      ...
# 21156     12        1
# 21157      8        2
# 21158     12        2
# 21159     11        4
# 21160      3        0
#
# [21161 rows x 7 columns]

# %%
Accidents_cleaned.select_dtypes(object)
# Out:
#               zona      via                  nommun           nomcom  \
# 0      Zona urbana       SE       CANOVES I SAMALUS  Valles Oriental
# 1        Carretera    N-240                  LLEIDA           Segria
# 2        Carretera     N-II    FORNELLS DE LA SELVA          Girones
# 3      Zona urbana       SE               BARCELONA       Barcelones
# 4      Zona urbana       SE                BADALONA       Barcelones
# ...            ...      ...                     ...              ...
# 21156  Zona urbana  BV-2002  SANT VICENC DELS HORTS   Baix Llobregat
# 21157  Zona urbana       SE                  LLEIDA           Segria
# 21158    Carretera    N-230            TORREFARRERA           Segria
# 21159  Zona urbana       SE                    REUS        Baix Camp
# 21160  Zona urbana       SE               TARRAGONA       Tarragones
#
#           nomdem f_morts f_ferits_greus f_ferits_lleus f_vianants_implicades  \
# 0      Barcelona      Si             No             Si                    Si
# 1         Lleida      Si             No             No                    Si
# 2         Girona      No             Si             No                    Si
# 3      Barcelona      Si             No             No                    Si
# 4      Barcelona      Si             No             Si                    Si
# ...          ...     ...            ...            ...                   ...
# 21156  Barcelona      No             Si             Si                    Si
# 21157     Lleida      Si             No             Si                    No
# 21158     Lleida      Si             No             Si                    Si
# 21159  Tarragona      Si             No             Si                    Si
# 21160  Tarragona      Si             No             Si                    No
#
#       f_ciclomotors_implicades f_motocicletes_implicades  \
# 0                           Si                        Si
# 1                           Si                        Si
# 2                           Si                        Si
# 3                           Si                        Si
# 4                           Si                        No
# ...                        ...                       ...
# 21156                       Si                        Si
# 21157                       Si                        Si
# 21158                       Si                        Si
# 21159                       Si                        No
# 21160                       Si                        Si
#
#       f_veh_lleugers_implicades f_veh_pesants_implicades  \
# 0                            No                       Si
# 1                            No                       Si
# 2                            No                       No
# 3                            No                       Si
# 4                            Si                       Si
# ...                         ...                      ...
# 21156                        No                       Si
# 21157                        No                       Si
# 21158                        No                       Si
# 21159                        No                       Si
# 21160                        No                       Si
#
#       f_altres_unit_implicades c_velocitat_via d_acc_amb_fuga d_boira  \
# 0                           No          60-100             No      No
# 1                           Si           20-60             No      No
# 2                           Si          60-100             No      No
# 3                           Si          60-100             No      No
# 4                           Si          60-100             No      No
# ...                        ...             ...            ...     ...
# 21156                       Si          60-100             No      No
# 21157                       Si          60-100             No      No
# 21158                       Si          60-100             No      No
# 21159                       Si          60-100             No      No
# 21160                       Si           20-60             No      No
#
#          d_caract_entorn d_carril_especial d_circulacio_mesures_esp  \
# 0                Desmunt                No                       No
# 1               A nivell                No                       No
# 2               A nivell                No                       No
# 3      Sense Especificar                No                       No
# 4      Sense Especificar                No                       No
# ...                  ...               ...                      ...
# 21156  Sense Especificar                No                       No
# 21157           A nivell                No                       No
# 21158           A nivell                No                       No
# 21159  Sense Especificar                No                       No
# 21160           A nivell                No                       No
#
#       d_climatologia d_func_esp_via       d_gravetat d_influit_boira  \
# 0          Bon temps     Via normal    Accident greu              No
# 1          Bon temps     Via normal    Accident greu              No
# 2          Bon temps   Via especial  Accident mortal              No
# 3          Bon temps     Via normal    Accident greu              No
# 4          Bon temps     Via normal    Accident greu              No
# ...              ...            ...              ...             ...
# 21156      Bon temps     Via normal  Accident mortal              No
# 21157      Bon temps     Via normal    Accident greu              No
# 21158      Bon temps     Via normal    Accident greu              No
# 21159      Bon temps     Via normal    Accident greu              No
# 21160      Bon temps     Via normal    Accident greu              No
#
#       d_influit_caract_entorn d_influit_circulacio d_influit_estat_clima  \
# 0                          No                   No                    No
# 1                          No                   No                    No
# 2                          No                   No                    No
# 3                          No                   No                    No
# 4                          No                   No                    No
# ...                       ...                  ...                   ...
# 21156                      No                   No                    No
# 21157                      No                   No                    No
# 21158                      No                   No                    No
# 21159                      No                   No                    No
# 21160                      No                   No                    No
#
#       d_influit_inten_vent d_influit_lluminositat d_influit_mesu_esp  \
# 0                       No                     No                 No
# 1                       No                     No                 No
# 2                       No                     No                 No
# 3                       No                     No                 No
# 4                       No                     No                 No
# ...                    ...                    ...                ...
# 21156                   No                     No                 No
# 21157                   No                     No                 No
# 21158                   No                     No                 No
# 21159                   No                     No                 No
# 21160                   No                     No                 No
#
#       d_influit_obj_calcada d_influit_solcs_rases d_influit_visibilitat  \
# 0                        No                    No                    No
# 1                        No                    No                    No
# 2                        No                    No                    No
# 3                        No                    No                    No
# 4                        No                    No                    No
# ...                     ...                   ...                   ...
# 21156                    No                    No                    No
# 21157                    No                    No                    No
# 21158                    No                    No                    No
# 21159                    No                    No                    No
# 21160                    No                    No                    Si
#
#                                d_inter_seccio d_limit_velocitat  \
# 0      Arribant o eixint intersecció fins 50m      Genérica via
# 1                          Dintre intersecció  Senyal velocitat
# 2                                   En secció  Senyal velocitat
# 3                          Dintre intersecció      Genérica via
# 4                          Dintre intersecció      Genérica via
# ...                                       ...               ...
# 21156                               En secció      Genérica via
# 21157                               En secció      Genérica via
# 21158                               En secció      Genérica via
# 21159                               En secció      Genérica via
# 21160                               En secció  Senyal velocitat
#
#                                   d_lluminositat d_regulacio_prioritat  \
# 0      De nit, il·luminació artificial suficient                    Si
# 1      De nit, il·luminació artificial suficient                    Si
# 2                               De dia, dia clar                    No
# 3      De nit, il·luminació artificial suficient                    Si
# 4                               De dia, dia clar                    Si
# ...                                          ...                   ...
# 21156                           De dia, dia clar                    No
# 21157                           De dia, dia clar                    No
# 21158                           De dia, dia clar                    No
# 21159                           De dia, dia clar                    No
# 21160                           De dia, dia clar                    No
#
#        d_sentits_via          d_subtipus_accident             d_subtipus_tram  \
# 0      Un sol sentit                       Encalç  Encreuament o altres tipus
# 1       Doble sentit        Resta sortides de via  Encreuament o altres tipus
# 2       Doble sentit            Col·lisió frontal                       Recta
# 3      Un sol sentit  Envestida (frontal lateral)  Encreuament o altres tipus
# 4      Un sol sentit            Caiguda en la via  Encreuament o altres tipus
# ...              ...                          ...                         ...
# 21156   Doble sentit                       Altres                       Recta
# 21157   Doble sentit                Atropellament                       Recta
# 21158   Doble sentit            Col·lisió frontal                       Recta
# 21159   Doble sentit  Envestida (frontal lateral)                       Recta
# 21160   Doble sentit                Atropellament                       Recta
#
#          d_subzona d_superficie  \
# 0      Zona urbana    Sec i net
# 1        Carretera    Sec i net
# 2        Carretera    Sec i net
# 3      Zona urbana    Sec i net
# 4      Zona urbana    Sec i net
# ...            ...          ...
# 21156   Travessera    Sec i net
# 21157  Zona urbana    Sec i net
# 21158    Carretera    Sec i net
# 21159  Zona urbana    Sec i net
# 21160  Zona urbana    Sec i net
#
#                                            d_tipus_via  d_titularitat_via  \
# 0      Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 1                               Carretera convencional            Estatal
# 2                               Carretera convencional            Estatal
# 3      Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 4      Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# ...                                                ...                ...
# 21156                           Carretera convencional  Sense Especificar
# 21157  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 21158                           Carretera convencional            Estatal
# 21159  Via urbana( inclou carrer i carrer residencial)  Sense Especificar
# 21160  Via urbana( inclou carrer i carrer residencial)          Municipal
#
#       d_tracat_altimetric d_vent    grupdialab gruphor  \
# 0       Sense especificar     No       Feiners     Nit
# 1                     Pla     No  CapDeSetmana     Nit
# 2         Rampa o pendent     No       Feiners   Tarda
# 3       Sense especificar     No  CapDeSetmana     Nit
# 4       Sense especificar     No  CapDeSetmana   Tarda
# ...                   ...    ...           ...     ...
# 21156   Sense especificar     No       Feiners    Matí
# 21157   Sense especificar     No       Feiners   Tarda
# 21158                 Pla     No       Feiners    Matí
# 21159   Sense especificar     No       Feiners    Matí
# 21160     Rampa o pendent     No       Feiners    Matí
#
#                                         tipacc   day_name
# 0               Col.lisió de vehicles en marxa     Monday
# 1      Sortida de la calcada sense especificar     Sunday
# 2               Col.lisió de vehicles en marxa     Monday
# 3               Col.lisió de vehicles en marxa   Saturday
# 4                         Bolcada a la calcada     Monday
# ...                                        ...        ...
# 21156                                   Altres    Tuesday
# 21157                            Atropellament  Wednesday
# 21158           Col.lisió de vehicles en marxa  Wednesday
# 21159           Col.lisió de vehicles en marxa     Friday
# 21160                            Atropellament     Monday
#
# [21161 rows x 50 columns]

# %% [markdown]
# # saving the cleaned data.

# %%
Accidents_cleaned.to_csv('Accidents_cleaned_more_categorized.csv', index=True, sep=',', encoding='utf-8')
